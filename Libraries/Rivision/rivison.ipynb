# %%
import pandas as pd
df = pd.read_csv('smartphones_cleaned_v6.csv')
pd.set_option('display.max_columns', 500)

# %%
df
# Out:
#     brand_name                            model  price  rating  has_5g  \
# 0      oneplus                    OnePlus 11 5G  54999    89.0    True
# 1      oneplus        OnePlus Nord CE 2 Lite 5G  19989    81.0    True
# 2      samsung            Samsung Galaxy A14 5G  16499    75.0    True
# 3     motorola             Motorola Moto G62 5G  14999    81.0    True
# 4       realme               Realme 10 Pro Plus  24999    82.0    True
# ..         ...                              ...    ...     ...     ...
# 975   motorola       Motorola Moto Edge S30 Pro  34990    83.0    True
# 976      honor                      Honor X8 5G  14990    75.0    True
# 977       poco  POCO X4 GT 5G (8GB RAM + 256GB)  28990    85.0    True
# 978   motorola             Motorola Moto G91 5G  19990    80.0    True
# 979    samsung           Samsung Galaxy M52s 5G  24990    74.0    True
#
#      has_nfc  has_ir_blaster processor_brand  num_cores  processor_speed  \
# ...

# %%
# top five samsung phones screen size columns

df.head()
# Out:
#   brand_name                      model  price  rating  has_5g  has_nfc  \
# 0    oneplus              OnePlus 11 5G  54999    89.0    True     True
# 1    oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0    True    False
# 2    samsung      Samsung Galaxy A14 5G  16499    75.0    True    False
# 3   motorola       Motorola Moto G62 5G  14999    81.0    True    False
# 4     realme         Realme 10 Pro Plus  24999    82.0    True    False
#
#    has_ir_blaster processor_brand  num_cores  processor_speed  \
# 0           False      snapdragon        8.0              3.2
# 1           False      snapdragon        8.0              2.2
# 2           False          exynos        8.0              2.4
# 3           False      snapdragon        8.0              2.2
# 4           False       dimensity        8.0              2.6
#
#    battery_capacity  fast_charging_available  fast_charging  ram_capacity  \
# 0            5000.0                        1          100.0          12.0
# ...

# %%
df["screen_size"]
# Out:
# 0      6.70
# 1      6.59
# 2      6.60
# 3      6.55
# 4      6.70
#        ...
# 975    6.67
# 976    6.50
# 977    6.60
# 978    6.80
# 979    6.50
# Name: screen_size, Length: 980, dtype: float64

# %%
df['brand_name']
# Out:
# 0       oneplus
# 1       oneplus
# 2       samsung
# 3      motorola
# 4        realme
#          ...
# 975    motorola
# 976       honor
# 977        poco
# 978    motorola
# 979     samsung
# Name: brand_name, Length: 980, dtype: object

# %%
df['model']
# Out:
# 0                        OnePlus 11 5G
# 1            OnePlus Nord CE 2 Lite 5G
# 2                Samsung Galaxy A14 5G
# 3                 Motorola Moto G62 5G
# 4                   Realme 10 Pro Plus
#                     ...
# 975         Motorola Moto Edge S30 Pro
# 976                        Honor X8 5G
# 977    POCO X4 GT 5G (8GB RAM + 256GB)
# 978               Motorola Moto G91 5G
# 979             Samsung Galaxy M52s 5G
# Name: model, Length: 980, dtype: object

# %%
df[['screen_size', 'model', 'brand_name']].head()
# Out:
#    screen_size                      model brand_name
# 0         6.70              OnePlus 11 5G    oneplus
# 1         6.59  OnePlus Nord CE 2 Lite 5G    oneplus
# 2         6.60      Samsung Galaxy A14 5G    samsung
# 3         6.55       Motorola Moto G62 5G   motorola
# 4         6.70         Realme 10 Pro Plus     realme

# %%
df[df["brand_name"]=="samsung"][["model","screen_size"]].sort_values("screen_size",ascending=False).head()
# Out:
#                                         model  screen_size
# 560                   Samsung Galaxy Z Fold 3         7.60
# 319                   Samsung Galaxy Z Fold 4         7.60
# 905  Samsung Galaxy Z Fold 4 (12GB RAM + 1TB)         7.60
# 593               Samsung Galaxy S20 Ultra 5G         6.90
# 362                  Samsung Galaxy S24 Ultra         6.83

# %%
df[df["brand_name"]=='oneplus'][['model', 'refresh_rate']].sort_values("refresh_rate",ascending=False).head(10)
# Out:
#                                     model  refresh_rate
# 510                        OnePlus 12 Pro           144
# 0                           OnePlus 11 5G           120
# 229  OnePlus 10 Pro 5G (12GB RAM + 256GB)           120
# 908                       OnePlus Ace Pro           120
# 871                            OnePlus 9T           120
# 857                        OnePlus Ace 5G           120
# 855                     OnePlus Nord 4 5G           120
# 640                        OnePlus Nord 5           120
# 624                OnePlus Nord 2 Lite 5G           120
# 526             OnePlus 10R Prime Edition           120

# %%
# which smartphone has sold more phones and which brand  

most_brandname_sold = df[['brand_name','screen_size']].max()
most_brandname_sold
# Out:
# brand_name      zte
# screen_size    8.03
# dtype: object

# %%
df[['brand_name', 'model']].min()
# Out:
# brand_name              apple
# model         Apple iPhone 11
# dtype: object

# %%
df[['brand_name', 'model']].value_counts()
# Out:
# brand_name  model
# apple       Apple iPhone 11                1
# samsung     Samsung Galaxy M53 5G          1
#             Samsung Galaxy M54 5G          1
#             Samsung Galaxy M62             1
#             Samsung Galaxy Note 10 Lite    1
#                                           ..
# oppo        OPPO A54                       1
#             OPPO A54 (4GB RAM + 128GB)     1
#             OPPO A54 (6GB RAM + 128GB)     1
#             OPPO A55 4G                    1
# zte         ZTE Axon 40 Ultra 5G           1
# Name: count, Length: 980, dtype: int64

# %%
df
# Out:
#     brand_name                            model  price  rating  has_5g  \
# 0      oneplus                    OnePlus 11 5G  54999    89.0    True
# 1      oneplus        OnePlus Nord CE 2 Lite 5G  19989    81.0    True
# 2      samsung            Samsung Galaxy A14 5G  16499    75.0    True
# 3     motorola             Motorola Moto G62 5G  14999    81.0    True
# 4       realme               Realme 10 Pro Plus  24999    82.0    True
# ..         ...                              ...    ...     ...     ...
# 975   motorola       Motorola Moto Edge S30 Pro  34990    83.0    True
# 976      honor                      Honor X8 5G  14990    75.0    True
# 977       poco  POCO X4 GT 5G (8GB RAM + 256GB)  28990    85.0    True
# 978   motorola             Motorola Moto G91 5G  19990    80.0    True
# 979    samsung           Samsung Galaxy M52s 5G  24990    74.0    True
#
#      has_nfc  has_ir_blaster processor_brand  num_cores  processor_speed  \
# ...

# %%
df1 = df['brand_name'].value_counts()

# %%
brand_counts = df['brand_name'].value_counts()
most_common_brand = brand_counts.idxmax()
most_common_brand
# Out:
# 'xiaomi'

# %%
most_brand_name = df['brand_name'].value_counts().idxmax()
most_brand_name
# Out:
# 'xiaomi'

# %%
most_rated_smartphone = df[['brand_name', 'rating']].value_counts().idxmax()
most_rated_smartphone
# Out:
# ('xiaomi', 83.0)

# %%
# Which smartphone has the highest battery capacity
most_highest_rated_smartphone = df.loc[df['battery_capacity'].idxmax(), ['brand_name', 'model', 'price']]
most_highest_rated_smartphone
# Out:
# brand_name          doogee
# model         Doogee V Max
# price                45999
# Name: 843, dtype: object

# %%
# How many smartphones in the dataset support 5G?

support_5g = df['has_5g'].sum()
support_5g
# Out:
# 549

# %% [markdown]
# Which brand offers the most 5G-enabled smartphones?

# %%
df[df['has_5g']==True]['brand_name'].value_counts().idxmax()
# Out:
# 'xiaomi'

# %% [markdown]
# Which processor brand is used in the most smartphones?

# %%
proceessor_counts = df['processor_brand'].value_counts().idxmax()
proceessor_counts
# Out:
# 'snapdragon'

# %% [markdown]
# Do smartphones with higher refresh rates also tend to have higher battery capacities?

# %%
higher_refresh = df[df('refresh_rate').value_counts() & (df['battery_capacity']).value_counts()]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 higher_refresh = df[df('refresh_rate').value_counts() & (df['battery_capacity']).value_counts()]
#
# TypeError: 'DataFrame' object is not callable

# %%
df['refresh_rate'].corr(df['battery_capacity'])

# %% [markdown]
# Among smartphones with 5G, which models balance the best combination of price, rating, and battery capacity?

# %%
df[df['has_5g']==True][['price', 'rating', 'battery_capacity']].value_counts().idxmax()
# Out:
# (15999, 78.0, 5000.0)

# %% [markdown]
# What is the average difference in price between smartphones with fast charging capabilities and those without?

# %%
fast_charging_supported = df[df['fast_charging_available']==True]['price'].mean()

# %%
fast_charging_not_supported = df[df['fast_charging_available']==False]['price'].mean()

# %%
difference = fast_charging_supported-fast_charging_not_supported
difference
# Out:
# 13065.840389001678

# %% [markdown]
# How does the number of rear cameras affect the smartphone rating?

# %%
df['num_rear_cameras'].corr(df['rating'])>0.5
# Out:
# True

# %% [markdown]
# df.head()

# %%
df.head()
# Out:
#   brand_name                      model  price  rating  has_5g  has_nfc  \
# 0    oneplus              OnePlus 11 5G  54999    89.0    True     True
# 1    oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0    True    False
# 2    samsung      Samsung Galaxy A14 5G  16499    75.0    True    False
# 3   motorola       Motorola Moto G62 5G  14999    81.0    True    False
# 4     realme         Realme 10 Pro Plus  24999    82.0    True    False
#
#    has_ir_blaster processor_brand  num_cores  processor_speed  \
# 0           False      snapdragon        8.0              3.2
# 1           False      snapdragon        8.0              2.2
# 2           False          exynos        8.0              2.4
# 3           False      snapdragon        8.0              2.2
# 4           False       dimensity        8.0              2.6
#
#    battery_capacity  fast_charging_available  fast_charging  ram_capacity  \
# 0            5000.0                        1          100.0          12.0
# ...

# %% [markdown]
# #### top 10 xiaomi phones having both ir blaster and nfc in order of highest price

# %%
df1 = df[(df['has_nfc']==True) & (df['has_ir_blaster']==True)]

# %%
df1[df1["brand_name"]=="xiaomi"].sort_values("price",ascending=False)[["model","price"]].head(10)
# Out:
#                                  model   price
# 765                 Xiaomi Mi Mix Fold  109990
# 235               Xiaomi Mix Fold 2 5G  106990
# 760                 Xiaomi 12 Ultra 5G   75999
# 202                 Xiaomi 13 Ultra 5G   71999
# 419                   Xiaomi 12S Ultra   69990
# 359                  Xiaomi 12T Pro 5G   59990
# 105                   Xiaomi 13 Pro 5G   58990
# 967                          Xiaomi 14   54999
# 947  Xiaomi Mi 10 5G (8GB RAM + 256GB)   54999
# 734    Xiaomi Redmi K60 Gaming Edition   54990

# %% [markdown]
# Which smartphone has the most RAM capacity?

# %%
df.loc[df['ram_capacity'].value_counts().idxmax(), ['brand_name','ram_capacity']]
# Out:
# brand_name      nothing
# ram_capacity        8.0
# Name: 8, dtype: object

# %% [markdown]
# How many smartphones support NFC?

# %%
df['has_nfc'].sum()
# Out:
# 393

# %% [markdown]
# Which smartphone has the highest refresh rate?

# %%
df.loc[df['refresh_rate'].max(), ['brand_name']]
# Out:
# brand_name    oppo
# Name: 240, dtype: object

# %% [markdown]
# What is the average price of smartphones in the dataset?

# %%
average_price = df['price'].mean()

# %%
average_price
# Out:
# 32520.504081632655

# %%
df['price'].median()
# Out:
# 19994.5

# %% [markdown]
# How many smartphones have more than 3 rear cameras?

# %%
df1 = df[df['num_rear_cameras']>3].shape[0] # shape[0] to count no of rows > 3 cameras
df1
# Out:
# 156

# %% [markdown]
# Which smartphone has the highest megapixel primary rear camera?

# %%
df.loc[df['primary_camera_rear'].max(), ['brand_name']]
# Out:
# brand_name    samsung
# Name: 200, dtype: object

# %% [markdown]
# What is the price range of smartphones with fast charging available?

# %%
df[df['fast_charging_available']==True]['price'].min()
# Out:
# 5785

# %%
df[df['fast_charging_available']==True]['price'].max()
# Out:
# 480000

# %% [markdown]
# How many smartphones offer more than 5000 mAh battery capacity?

# %%
df[df['battery_capacity']>5000].shape[0]
# Out:
# 113

# %% [markdown]
# Which smartphone has the fastest processor speed?

# %%
df.loc[df['processor_speed'].idxmax(), ['brand_name', 'model', 'processor_brand']]
# Out:
# brand_name                   apple
# model              Apple iPhone 14
# processor_brand             bionic
# Name: 6, dtype: object

# %% [markdown]
# How many smartphones support memory extension?

# %%
df['extended_memory_available'].sum()
# Out:
# 618

# %% [markdown]
# Which smartphone has the highest resolution screen?

# %%
df.loc[(df['resolution_height']*df['resolution_width']).idxmax(), ['brand_name', 'model','resolution_width', 'resolution_height']]
# Out:
# brand_name                        sony
# model                Sony Xperia Pro-I
# resolution_width                  1644
# resolution_height                 3840
# Name: 368, dtype: object

# %% [markdown]
# Lamba fucntion

# %%
df['price'].apply(lambda x: x/2)
# Out:
# 0      27499.5
# 1       9994.5
# 2       8249.5
# 3       7499.5
# 4      12499.5
#         ...
# 975    17495.0
# 976     7495.0
# 977    14495.0
# 978     9995.0
# 979    12495.0
# Name: price, Length: 980, dtype: float64

# %%
def half_marks(x):
    return x/2

# %%
df['HAlf_Price'] = df['price'].apply(half_marks)

# %%
df
# Out:
#     brand_name                            model  price  rating  has_5g  \
# 0      oneplus                    OnePlus 11 5G  54999    89.0    True
# 1      oneplus        OnePlus Nord CE 2 Lite 5G  19989    81.0    True
# 2      samsung            Samsung Galaxy A14 5G  16499    75.0    True
# 3     motorola             Motorola Moto G62 5G  14999    81.0    True
# 4       realme               Realme 10 Pro Plus  24999    82.0    True
# ..         ...                              ...    ...     ...     ...
# 975   motorola       Motorola Moto Edge S30 Pro  34990    83.0    True
# 976      honor                      Honor X8 5G  14990    75.0    True
# 977       poco  POCO X4 GT 5G (8GB RAM + 256GB)  28990    85.0    True
# 978   motorola             Motorola Moto G91 5G  19990    80.0    True
# 979    samsung           Samsung Galaxy M52s 5G  24990    74.0    True
#
#      has_nfc  has_ir_blaster processor_brand  num_cores  processor_speed  \
# ...

# %%
df['brand_name'].apply(len)
# Out:
# 0      7
# 1      7
# 2      7
# 3      8
# 4      6
#       ..
# 975    8
# 976    5
# 977    4
# 978    8
# 979    7
# Name: brand_name, Length: 980, dtype: int64

# %% [markdown]
# # MAP Function

# %% [markdown]
# #use in charge available OR NOT

# %%
df['fast_charging_available']=df['fast_charging_available'].map({1:True, 0:False})

# %%
df['fast_charging_available']
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 975    True
# 976    True
# 977    True
# 978    True
# 979    True
# Name: fast_charging_available, Length: 980, dtype: bool

# %% [markdown]
# # Drop columns

# %%
df.drop('HAlf_Price', axis = 1)
# Out:
#     brand_name                            model  price  rating  has_5g  \
# 0      oneplus                    OnePlus 11 5G  54999    89.0    True
# 1      oneplus        OnePlus Nord CE 2 Lite 5G  19989    81.0    True
# 2      samsung            Samsung Galaxy A14 5G  16499    75.0    True
# 3     motorola             Motorola Moto G62 5G  14999    81.0    True
# 4       realme               Realme 10 Pro Plus  24999    82.0    True
# ..         ...                              ...    ...     ...     ...
# 975   motorola       Motorola Moto Edge S30 Pro  34990    83.0    True
# 976      honor                      Honor X8 5G  14990    75.0    True
# 977       poco  POCO X4 GT 5G (8GB RAM + 256GB)  28990    85.0    True
# 978   motorola             Motorola Moto G91 5G  19990    80.0    True
# 979    samsung           Samsung Galaxy M52s 5G  24990    74.0    True
#
#      has_nfc  has_ir_blaster processor_brand  num_cores  processor_speed  \
# ...

# %% [markdown]
# How many smartphones offer more than 5000 mAh battery capacity?

# %% [markdown]
# How many smartphones support memory extension?

# %%
df['extended_memory_available'].sum()
# Out:
# 618

# %% [markdown]
# What is the most common operating system in the dataset?

# %%
df['os'].value_counts().idxmax()
# Out:
# 'android'

# %% [markdown]
# Which smartphone has the highest internal memory capacity?

# %%
df.loc[df['internal_memory'].idxmax(), ['brand_name', 'model']]
# Out:
# brand_name                            apple
# model         Apple iPhone 14 Pro Max (1TB)
# Name: 288, dtype: object

# %%
df[['brand_name','internal_memory']].max()
# Out:
# brand_name            zte
# internal_memory    1024.0
# dtype: object

# %%
df.loc[0, 'brand_name']
# Out:
# 'oneplus'

# %%
df.sort_values(by='processor_speed', ascending=False)
# Out:
#     brand_name                         model   price  rating  has_5g  has_nfc  \
# 923      apple     Apple iPhone 13 Pro (1TB)  147900    84.0    True     True
# 275      apple          Apple iPhone 13 Mini   64900    79.0    True     True
# 344      apple       Apple iPhone 13 (256GB)   72999    79.0    True     True
# 813      apple       Apple iPhone 13 (512GB)   91999    80.0    True     True
# 321      apple  Apple iPhone 14 Plus (256GB)   84999    83.0    True     True
# ..         ...                           ...     ...     ...     ...      ...
# 892      apple          Apple iPhone 15 Plus   84990    75.0    True     True
# 910    samsung            Samsung Galaxy M35   22999    74.0   False     True
# 911    samsung            Samsung Galaxy A05   12990    63.0   False    False
# 973     google            Google Pixel 8 Pro   70990    80.0    True     True
# 979    samsung        Samsung Galaxy M52s 5G   24990    74.0    True    False
#
# ...

# %% [markdown]
# Group data by one or more columns and perform aggregate functions (like mean, sum, count).

# %%
df.groupby('brand_name')['price'].mean()
# Out:
# brand_name
# apple         95966.521739
# asus          74709.428571
# blackview      8990.000000
# blu           14990.000000
# cat           14999.000000
# cola          14999.000000
# doogee        30499.000000
# duoqin         9990.000000
# gionee         6896.000000
# google        44332.571429
# honor         30301.846154
# huawei        80177.250000
# ikall          7632.333333
# infinix       14664.793103
# iqoo          30301.875000
# itel           5811.000000
# jio            7159.250000
# lava          11246.750000
# leeco         10999.000000
# leitz        124990.000000
# lenovo        53494.500000
# letv           6165.666667
# lg            63329.333333
# lyf            3940.000000
# micromax       6929.333333
# motorola      24099.923077
# nokia         24630.769231
# nothing       31195.400000
# nubia         49827.833333
# oneplus       35858.571429
# oppo          29650.034091
# oukitel       26293.000000
# poco          18479.195122
# realme        17461.422680
# ...

# %% [markdown]
# df[].str.contain("abc"): it give the how many the number of product with the match of this "abc";

# %%
df[df['model'].str.contains('Pro')]
# Out:
#     brand_name                          model   price  rating  has_5g  \
# 4       realme             Realme 10 Pro Plus   24999    82.0    True
# 7       xiaomi  Xiaomi Redmi Note 12 Pro Plus   29999    86.0    True
# 10      realme                  Realme 10 Pro   18999    82.0    True
# 12      xiaomi    Xiaomi Redmi Note 12 Pro 5G   24762    79.0    True
# 17        oppo           OPPO Reno 9 Pro Plus   45999    86.0    True
# ..         ...                            ...     ...     ...     ...
# 923      apple      Apple iPhone 13 Pro (1TB)  147900    84.0    True
# 955    samsung   Samsung Galaxy A9 Pro (2019)   39990    78.0   False
# 959  blackview           Blackview BV5200 Pro    8990    67.0    True
# 973     google             Google Pixel 8 Pro   70990    80.0    True
# 975   motorola     Motorola Moto Edge S30 Pro   34990    83.0    True
#
#      has_nfc  has_ir_blaster processor_brand  num_cores  processor_speed  \
# ...

# %% [markdown]
# Which brand offers the most smartphones with 128GB of internal memory?

# %%
df[df['internal_memory']==128]['brand_name'].value_counts().idxmax()
# Out:
# 'samsung'
