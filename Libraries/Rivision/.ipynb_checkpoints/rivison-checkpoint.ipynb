# %%
import pandas as pd
df = pd.read_csv('smartphones_cleaned_v6.csv')

# %%
df
# Out:
#     brand_name                            model  price  rating  has_5g  \
# 0      oneplus                    OnePlus 11 5G  54999    89.0    True
# 1      oneplus        OnePlus Nord CE 2 Lite 5G  19989    81.0    True
# 2      samsung            Samsung Galaxy A14 5G  16499    75.0    True
# 3     motorola             Motorola Moto G62 5G  14999    81.0    True
# 4       realme               Realme 10 Pro Plus  24999    82.0    True
# ..         ...                              ...    ...     ...     ...
# 975   motorola       Motorola Moto Edge S30 Pro  34990    83.0    True
# 976      honor                      Honor X8 5G  14990    75.0    True
# 977       poco  POCO X4 GT 5G (8GB RAM + 256GB)  28990    85.0    True
# 978   motorola             Motorola Moto G91 5G  19990    80.0    True
# 979    samsung           Samsung Galaxy M52s 5G  24990    74.0    True
#
#      has_nfc  has_ir_blaster processor_brand  num_cores  processor_speed  ...  \
# ...

# %%
# top five samsung phones screen size columns

df.head()
# Out:
#   brand_name                      model  price  rating  has_5g  has_nfc  \
# 0    oneplus              OnePlus 11 5G  54999    89.0    True     True
# 1    oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0    True    False
# 2    samsung      Samsung Galaxy A14 5G  16499    75.0    True    False
# 3   motorola       Motorola Moto G62 5G  14999    81.0    True    False
# 4     realme         Realme 10 Pro Plus  24999    82.0    True    False
#
#    has_ir_blaster processor_brand  num_cores  processor_speed  ...  \
# 0           False      snapdragon        8.0              3.2  ...
# 1           False      snapdragon        8.0              2.2  ...
# 2           False          exynos        8.0              2.4  ...
# 3           False      snapdragon        8.0              2.2  ...
# 4           False       dimensity        8.0              2.6  ...
#
#    refresh_rate  num_rear_cameras  num_front_cameras       os  \
# 0           120                 3                1.0  android
# ...

# %%
df["screen_size"]
# Out:
# 0      6.70
# 1      6.59
# 2      6.60
# 3      6.55
# 4      6.70
#        ...
# 975    6.67
# 976    6.50
# 977    6.60
# 978    6.80
# 979    6.50
# Name: screen_size, Length: 980, dtype: float64

# %%
df['brand_name']
# Out:
# 0       oneplus
# 1       oneplus
# 2       samsung
# 3      motorola
# 4        realme
#          ...
# 975    motorola
# 976       honor
# 977        poco
# 978    motorola
# 979     samsung
# Name: brand_name, Length: 980, dtype: object

# %%
df['model']
# Out:
# 0                        OnePlus 11 5G
# 1            OnePlus Nord CE 2 Lite 5G
# 2                Samsung Galaxy A14 5G
# 3                 Motorola Moto G62 5G
# 4                   Realme 10 Pro Plus
#                     ...
# 975         Motorola Moto Edge S30 Pro
# 976                        Honor X8 5G
# 977    POCO X4 GT 5G (8GB RAM + 256GB)
# 978               Motorola Moto G91 5G
# 979             Samsung Galaxy M52s 5G
# Name: model, Length: 980, dtype: object

# %%
df[['screen_size', 'model', 'brand_name']].head()
# Out:
#    screen_size                      model brand_name
# 0         6.70              OnePlus 11 5G    oneplus
# 1         6.59  OnePlus Nord CE 2 Lite 5G    oneplus
# 2         6.60      Samsung Galaxy A14 5G    samsung
# 3         6.55       Motorola Moto G62 5G   motorola
# 4         6.70         Realme 10 Pro Plus     realme

# %%
df[df["brand_name"]=="samsung"][["model","screen_size"]].sort_values("screen_size",ascending=False).head()
# Out:
#                                         model  screen_size
# 560                   Samsung Galaxy Z Fold 3         7.60
# 319                   Samsung Galaxy Z Fold 4         7.60
# 905  Samsung Galaxy Z Fold 4 (12GB RAM + 1TB)         7.60
# 593               Samsung Galaxy S20 Ultra 5G         6.90
# 362                  Samsung Galaxy S24 Ultra         6.83

# %%
df[df["brand_name"]=='oneplus'][['model', 'refresh_rate	']].sort_values('refresh_rate',ascending=False).head(10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 df[df["brand_name"]=='oneplus'][['model', 'refresh_rate	']].sort_values('refresh_rate',ascending=False).head(10)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:3767, in DataFrame.__getitem__(self, key)
#    3765     if is_iterator(key):
#    3766         key = list(key)
# -> 3767     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3769 # take() does not accept boolean indexers
#    3770 if getattr(indexer, "dtype", None) == bool:
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:5877, in Index._get_indexer_strict(self, key, axis_name)
#    5874 else:
#    5875     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5877 self._raise_if_missing(keyarr, indexer, axis_name)
#    5879 keyarr = self.take(indexer)
# ...
