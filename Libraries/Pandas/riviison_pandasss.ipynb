# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# import pandas
import numpy as np
import pandas as pd

# %% [markdown]
# <!-- Series from lists  -->

# %% [markdown]
# Series and lists

# %%
#string ko hi series bolata hai..
 
country = ["India", "China", "USA", "Nepal", "Srilanka"]

pd.Series(country
          )
# Out:
# 0       India
# 1       China
# 2         USA
# 3       Nepal
# 4    Srilanka
# dtype: object

# %%
# integers 
runs = [12,13,14,45,56]
pd.Series(runs)
# Out:
# 0    12
# 1    13
# 2    14
# 3    45
# 4    56
# dtype: int64

# %%
# coustom index

marks = [67,6,8,78,99]
subjects = ['A','B','C', 'D', 'E']
pd.Series(marks, index=subjects)
# Out:
# A    67
# B     6
# C     8
# D    78
# E    99
# dtype: int64

# %%
# setting a name
marks = pd.Series(marks, index=subjects, name="nitish kr marks")
marks
# Out:
# A    67
# B     6
# C     8
# D    78
# E    99
# Name: nitish kr marks, dtype: int64

# %%
# Series from dict


data = {'a': 10, 'b': 20, 'c': 30}


marks_series = pd.Series(data, name="Nitish ke marks")

print(series)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[43], line 9
#       4 data = {'a': 10, 'b': 20, 'c': 30}
#       7 marks_series = pd.Series(data, name="Nitish ke marks")
# ----> 9 print(series)
#
# NameError: name 'series' is not defined

# %% [markdown]
# Series atrribute

# %%
# size

marks_series.size
# Out:
# 3

# %%
# dtype
marks_series.dtype
# Out:
# dtype('int64')

# %%
# name 
marks_series.name
# Out:
# 'Nitish ke marks'

# %%
# is_unique
marks_series.is_unique

pd.Series([1,1,2,3,4,5,6]).is_unique
# Out:
# False

# %%
# index
marks_series.index
# Out:
# Index(['a', 'b', 'c'], dtype='object')

# %%
# values
marks_series.values
# Out:
# array([10, 20, 30])

# %%
marks.values
# Out:
# array([67,  6,  8, 78, 99])

# %% [markdown]
# Series and read_csv

# %%
kohli = pd.read_excel('kohli_ipl_dataset.xlsx', index_col='Matches Played')

# %%
kohli
# Out:
#                 Year  Runs Scored  Average  Strike Rate  Fours  Sixes
# Matches Played
# 16              2011          599    37.44       130.61     92     36
# 14              2012          662    47.29       136.50     98     47
# 16              2013          448    28.00       143.79     46     38
# 11              2014          682    62.00       149.66     78     27
# 13              2015          405    31.15       136.10     96     26
# 10              2016          527    52.70       140.77     46     18
# 13              2017          405    31.15       132.69     84     34
# 18              2018          354    19.67       149.65     99     21
# 17              2019          564    33.18       132.49     34     25
# 13              2020          521    40.08       131.65     81     19

# %%
type(kohli)
# Out:
# pandas.core.frame.DataFrame

# %%
subscribe = pd.read_excel('youtube_subscriber_gain_and_downloads_100_rows.xlsx', index_col='Total Subscribers')

# %%
subscribe.head()
# Out:
#                         Date Video ID  Subscribers Gained    Video Title  \
# Total Subscribers
# 10181             2025-01-01     V001                 181  Video Title 1
# 10422             2025-01-02     V002                 241  Video Title 2
# 10708             2025-01-03     V003                 286  Video Title 3
# 10864             2025-01-04     V004                 156  Video Title 4
# 11318             2025-01-05     V005                 454  Video Title 5
#
#                    Downloads  Download Change  Gain-to-Download Ratio
# Total Subscribers
# 10181                   2607              636                0.069402
# 10422                    728              696                0.330590
# 10708                   2787              272                0.102582
# 10864                    836              564                0.186380
# 11318                   1227              739                0.369707

# %%
# with 2 columns

movies = pd.read_excel('bollywood_fake_dataset.xlsx')

# %%
type(movies)
# Out:
# pandas.core.frame.DataFrame

# %%
movies
# Out:
#               Actor  Movies Released  \
# 0  Amitabh Bachchan               11
# 1    Shah Rukh Khan               10
# 2        Aamir Khan                5
# 3       Salman Khan               11
# 4     Ranbir Kapoor               16
# 5  Deepika Padukone               15
# 6   Priyanka Chopra               12
# 7      Katrina Kaif               17
# 8        Alia Bhatt               10
# 9    Hrithik Roshan               18
#
#    Average Box Office Collection (in Crores)  Awards Won  Hit Movies
# 0                                       3080           7           9
# 1                                       4430           2           4
# 2                                       4220           8           2
# 3                                       3100           4           9
# 4                                       3620           7           3
# 5                                       3220           8           3
# ...

# %%
movies1 = movies['Movies Released']
type(movies1)
# Out:
# pandas.core.series.Series

# %%
movies1
# Out:
# 0    11
# 1    10
# 2     5
# 3    11
# 4    16
# 5    15
# 6    12
# 7    17
# 8    10
# 9    18
# Name: Movies Released, dtype: int64

# %%
kohli.head()
# Out:
#                 Year  Runs Scored  Average  Strike Rate  Fours  Sixes
# Matches Played
# 16              2011          599    37.44       130.61     92     36
# 14              2012          662    47.29       136.50     98     47
# 16              2013          448    28.00       143.79     46     38
# 11              2014          682    62.00       149.66     78     27
# 13              2015          405    31.15       136.10     96     26

# %%
kohli.tail()
# Out:
#                 Year  Runs Scored  Average  Strike Rate  Fours  Sixes
# Matches Played
# 10              2016          527    52.70       140.77     46     18
# 13              2017          405    31.15       132.69     84     34
# 18              2018          354    19.67       149.65     99     21
# 17              2019          564    33.18       132.49     34     25
# 13              2020          521    40.08       131.65     81     19

# %%
# sample  : it select randomly 
movies.sample()
# Out:
#              Actor  Movies Released  \
# 6  Priyanka Chopra               12
#
#    Average Box Office Collection (in Crores)  Awards Won  Hit Movies
# 6                                       2280           7           5

# %%
kohli.sample(5)
# Out:
#                 Year  Runs Scored  Average  Strike Rate  Fours  Sixes
# Matches Played
# 13              2020          521    40.08       131.65     81     19
# 10              2016          527    52.70       140.77     46     18
# 16              2013          448    28.00       143.79     46     38
# 18              2018          354    19.67       149.65     99     21
# 13              2017          405    31.15       132.69     84     34

# %%
# value_counts()

kohli.value_counts()
# Out:
# Year  Runs Scored  Average  Strike Rate  Fours  Sixes
# 2011  599          37.44    130.61       92     36       1
# 2012  662          47.29    136.50       98     47       1
# 2013  448          28.00    143.79       46     38       1
# 2014  682          62.00    149.66       78     27       1
# 2015  405          31.15    136.10       96     26       1
# 2016  527          52.70    140.77       46     18       1
# 2017  405          31.15    132.69       84     34       1
# 2018  354          19.67    149.65       99     21       1
# 2019  564          33.18    132.49       34     25       1
# 2020  521          40.08    131.65       81     19       1
# Name: count, dtype: int64

# %%
movies.value_counts()
# Out:
# Actor             Movies Released  Average Box Office Collection (in Crores)  Awards Won  Hit Movies
# Aamir Khan        5                4220                                       8           2             1
# Alia Bhatt        10               4100                                       2           7             1
# Amitabh Bachchan  11               3080                                       7           9             1
# Deepika Padukone  15               3220                                       8           3             1
# Hrithik Roshan    18               2470                                       2           3             1
# Katrina Kaif      17               3690                                       4           3             1
# Priyanka Chopra   12               2280                                       7           5             1
# Ranbir Kapoor     16               3620                                       7           3             1
# ...

# %%
movies.sort_values
# Out:
# <bound method DataFrame.sort_values of               Actor  Movies Released  \
# 0  Amitabh Bachchan               11
# 1    Shah Rukh Khan               10
# 2        Aamir Khan                5
# 3       Salman Khan               11
# 4     Ranbir Kapoor               16
# 5  Deepika Padukone               15
# 6   Priyanka Chopra               12
# 7      Katrina Kaif               17
# 8        Alia Bhatt               10
# 9    Hrithik Roshan               18
#
#    Average Box Office Collection (in Crores)  Awards Won  Hit Movies
# 0                                       3080           7           9
# 1                                       4430           2           4
# 2                                       4220           8           2
# 3                                       3100           4           9
# 4                                       3620           7           3
# 5                                       3220           8           3
# ...

# %%
kohli = kohli['Runs Scored']

# %%
type(kohli)
# Out:
# pandas.core.series.Series

# %%
kohli.sort_values(ascending=False).head(1).values[0]
# Out:
# 682

# %% [markdown]
# sort value change for temporary..

# %%
kohli.sort_values(ascending=False)
# Out:
# Matches Played
# 11    682
# 14    662
# 16    599
# 17    564
# 10    527
# 13    521
# 16    448
# 13    405
# 13    405
# 18    354
# Name: Runs Scored, dtype: int64

# %% [markdown]
# here, it will be change in the datasets..

# %%
movies.sort_values(by='Awards Won' ,inplace=True)

# %%
movies
# Out:
#               Actor  Movies Released  \
# 1    Shah Rukh Khan               10
# 8        Alia Bhatt               10
# 9    Hrithik Roshan               18
# 3       Salman Khan               11
# 7      Katrina Kaif               17
# 0  Amitabh Bachchan               11
# 4     Ranbir Kapoor               16
# 6   Priyanka Chopra               12
# 2        Aamir Khan                5
# 5  Deepika Padukone               15
#
#    Average Box Office Collection (in Crores)  Awards Won  Hit Movies
# 1                                       4430           2           4
# 8                                       4100           2           7
# 9                                       2470           2           3
# 3                                       3100           4           9
# 7                                       3690           4           3
# 0                                       3080           7           9
# ...

# %%
# sort_index() 
movies
# Out:
#               Actor  Movies Released  \
# 1    Shah Rukh Khan               10
# 8        Alia Bhatt               10
# 9    Hrithik Roshan               18
# 3       Salman Khan               11
# 7      Katrina Kaif               17
# 0  Amitabh Bachchan               11
# 4     Ranbir Kapoor               16
# 6   Priyanka Chopra               12
# 2        Aamir Khan                5
# 5  Deepika Padukone               15
#
#    Average Box Office Collection (in Crores)  Awards Won  Hit Movies
# 1                                       4430           2           4
# 8                                       4100           2           7
# 9                                       2470           2           3
# 3                                       3100           4           9
# 7                                       3690           4           3
# 0                                       3080           7           9
# ...

# %% [markdown]
# change the index in the datasets also

# %%
kohli.sort_index(ascending=False, inplace=True)

# %%
kohli
# Out:
# Matches Played
# 18    354
# 17    564
# 16    599
# 16    448
# 14    662
# 13    405
# 13    405
# 13    521
# 11    682
# 10    527
# Name: Runs Scored, dtype: int64

# %% [markdown]
# # Series Maths Methods

# %% [markdown]
# size count also missiing values, and count not count misising  values..

# %%
# count 

kohli.count()
# Out:
# 10

# %%
# sum -> product
kohli.sum()
# Out:
# 5167

# %%
 # mean -> median -> mode -> std -> var
 
kohli.mean()
# Out:
# 516.7

# %%
print(kohli.median())
# Out:
# 524.0

# %%
print(kohli.mode())
# Out:
# 0    405
# Name: Runs Scored, dtype: int64

# %%
kohli.std()
# Out:
# 112.4060595440576

# %%
kohli.var()
# Out:
# 12635.122222222222

# %%
kohli.mean()
# Out:
# 516.7

# %%
kohli.max()
# Out:
# 682

# %%
subscribe
# Out:
#                         Date Video ID  Subscribers Gained      Video Title  \
# Total Subscribers
# 10181             2025-01-01     V001                 181    Video Title 1
# 10422             2025-01-02     V002                 241    Video Title 2
# 10708             2025-01-03     V003                 286    Video Title 3
# 10864             2025-01-04     V004                 156    Video Title 4
# 11318             2025-01-05     V005                 454    Video Title 5
# ...                      ...      ...                 ...              ...
# 40208             2025-04-06     V096                 422   Video Title 96
# 40560             2025-04-07     V097                 352   Video Title 97
# 40756             2025-04-08     V098                 196   Video Title 98
# 41126             2025-04-09     V099                 370   Video Title 99
# 41394             2025-04-10     V100                 268  Video Title 100
#
# ...

# %%
subscribe.describe()
# Out:
#                       Date  Subscribers Gained    Downloads  Download Change  \
# count                  100          100.000000   100.000000       100.000000
# mean   2025-02-19 12:00:00          313.940000  1768.380000       329.440000
# min    2025-01-01 00:00:00          100.000000   524.000000      -184.000000
# 25%    2025-01-25 18:00:00          234.750000  1025.500000       147.500000
# 50%    2025-02-19 12:00:00          315.000000  1822.500000       365.000000
# 75%    2025-03-16 06:00:00          400.250000  2444.250000       537.500000
# max    2025-04-10 00:00:00          497.000000  2920.000000       797.000000
# std                    NaN          104.883179   750.925567       270.665298
#
#        Gain-to-Download Ratio
# count              100.000000
# mean                 0.221955
# min                  0.049457
# 25%                  0.117846
# 50%                  0.178950
# 75%                  0.294718
# max                  0.699088
# ...

# %% [markdown]
# # Series Indexing

# %% [markdown]
# series indexing works on positive index number..

# %%
#  integer indexing

x = pd.Series([12,13,14,45,5,4,56,45,45])

# %%
x[1]
# Out:
# 13

# %%
subscribe['Subscribers Gained'].value_counts()
# Out:
# Subscribers Gained
# 367    2
# 422    2
# 345    2
# 339    2
# 255    2
#       ..
# 450    1
# 319    1
# 484    1
# 317    1
# 268    1
# Name: count, Length: 93, dtype: int64

# %%
x[3]
# Out:
# 45

# %%
kohli
# Out:
# Matches Played
# 18    354
# 17    564
# 16    599
# 16    448
# 14    662
# 13    405
# 13    405
# 13    521
# 11    682
# 10    527
# Name: Runs Scored, dtype: int64

# %%
kohli[18]
# Out:
# 354

# %%
# slicing : 

kohli[5:16]
# Out:
# Matches Played
# 13    405
# 13    405
# 13    521
# 11    682
# 10    527
# Name: Runs Scored, dtype: int64

# %%
# negateive slicing 

kohli[-5:]
# Out:
# Matches Played
# 13    405
# 13    405
# 13    521
# 11    682
# 10    527
# Name: Runs Scored, dtype: int64

# %%
kohli[::2]
# Out:
# Matches Played
# 18    354
# 16    599
# 14    662
# 13    405
# 11    682
# Name: Runs Scored, dtype: int64

# %%
movies[::2]
# Out:
#               Actor  Movies Released  \
# 0  Amitabh Bachchan               11
# 2        Aamir Khan                5
# 4     Ranbir Kapoor               16
# 6   Priyanka Chopra               12
# 8        Alia Bhatt               10
#
#    Average Box Office Collection (in Crores)  Awards Won  Hit Movies
# 0                                       3080           7           9
# 2                                       4220           8           2
# 4                                       3620           7           3
# 6                                       2280           7           5
# 8                                       4100           2           7

# %%
movies[3:5:2]
# Out:
#          Actor  Movies Released  Average Box Office Collection (in Crores)  \
# 3  Salman Khan               11                                       3100
#
#    Awards Won  Hit Movies
# 3           4           9

# %%
 # fancy indexing
subscribe['Gain-to-Download Ratio']
# Out:
# Total Subscribers
# 10181    0.069402
# 10422    0.330590
# 10708    0.102582
# 10864    0.186380
# 11318    0.369707
#            ...
# 40208    0.263256
# 40560    0.129317
# 40756    0.196985
# 41126    0.126886
# 41394    0.121103
# Name: Gain-to-Download Ratio, Length: 100, dtype: float64

# %%
subscribe['Video Title'].isna().sum()
# Out:
# 0

# %% [markdown]
# Edting Series

# %%
# using indexing
marks_series
# Out:
# a    10
# b    20
# c    30
# Name: Nitish ke marks, dtype: int64

# %%
marks_series[1] = 100
# Out:
# /var/folders/kq/d8w7gp1d5dn0q7qm6tzkh4pc0000gn/T/ipykernel_46701/1733563835.py:1: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   marks_series[1] = 100

# %%
marks_series
# Out:
# a     10
# b    100
# c     30
# Name: Nitish ke marks, dtype: int64

# %%
# what if an index does not exits..
marks_series['d'] = 99

# %%
marks_series
# Out:
# a     10
# b    100
# c     30
# d     99
# Name: Nitish ke marks, dtype: int64

# %%
marks_series
# Out:
# a     10
# b    100
# c     30
# d     99
# Name: Nitish ke marks, dtype: int64

# %%
# slicing 
runs
# Out:
# [12, 13, 14, 45, 56]

# %%
runs[2:5] = [100, 100]

# %%
runs
# Out:
# [12, 13, 100, 100]

# %%
# fancy indexing
# Out:
# list

# %%
# using index label
movies['Salman Khan'] = '3100'
movies
# Out:
#               Actor  Movies Released  \
# 0  Amitabh Bachchan               11
# 1    Shah Rukh Khan               10
# 2        Aamir Khan                5
# 3       Salman Khan               11
# 4     Ranbir Kapoor               16
# 5  Deepika Padukone               15
# 6   Priyanka Chopra               12
# 7      Katrina Kaif               17
# 8        Alia Bhatt               10
# 9    Hrithik Roshan               18
#
#    Average Box Office Collection (in Crores)  Awards Won  Hit Movies  \
# 0                                       3080           7           9
# 1                                       4430           2           4
# 2                                       4220           8           2
# 3                                       3100           4           9
# 4                                       3620           7           3
# 5                                       3220           8           3
# ...

# %% [markdown]
# Series and Python FUcntionality

# %%
subscribe = subscribe['Subscribers Gained']

# %%
# len/type/dir/sorted/max/min

print(len(subscribe))
print(type(subscribe))
print(dir(subscribe))
print(sorted(subscribe))
print(min(subscribe))
print(max(subscribe))
print(len(subscribe))
# Out:
# 100
# <class 'pandas.core.series.Series'>
# ...

# %%
# type conversion()
list(kohli)
# Out:
# [354, 564, 599, 448, 662, 405, 405, 521, 682, 527]

# %%
dict(kohli)
# Out:
# {18: 354,
#  17: 564,
#  16: Matches Played
#  16    599
#  16    448
#  Name: Runs Scored, dtype: int64,
#  14: 662,
#  13: Matches Played
#  13    405
#  13    405
#  13    521
#  Name: Runs Scored, dtype: int64,
#  11: 682,
#  10: 527}

# %%
# membership operator : 
movies
# Out:
#               Actor  Movies Released  \
# 0  Amitabh Bachchan               11
# 1    Shah Rukh Khan               10
# 2        Aamir Khan                5
# 3       Salman Khan               11
# 4     Ranbir Kapoor               16
# 5  Deepika Padukone               15
# 6   Priyanka Chopra               12
# 7      Katrina Kaif               17
# 8        Alia Bhatt               10
# 9    Hrithik Roshan               18
#
#    Average Box Office Collection (in Crores)  Awards Won  Hit Movies  \
# 0                                       3080           7           9
# 1                                       4430           2           4
# 2                                       4220           8           2
# 3                                       3100           4           9
# 4                                       3620           7           3
# 5                                       3220           8           3
# ...

# %%
'Priyanka Chopra' in movies
# Out:
# True

# %%
18 in movies
# Out:
# False

# %%
18 in movies.values
# Out:
# True

# %%
# looping
for i in movies:
    print(i)
# Out:
# Actor
# Movies Released
# Average Box Office Collection (in Crores)
# Awards Won
# Hit Movies
# Salman Khan

# %%
# arithmetic operators(braodcasting)

marks_series
# Out:
# a     10
# b    100
# c     30
# d     99
# Name: Nitish ke marks, dtype: int64

# %%
100 -marks_series
# Out:
# a    90
# b     0
# c    70
# d     1
# Name: Nitish ke marks, dtype: int64

# %%
# relationsal operators

# %%
kohli >= 500
# Out:
# Matches Played
# 18    False
# 17     True
# 16     True
# 16    False
# 14     True
# 13    False
# 13    False
# 13     True
# 11     True
# 10     True
# Name: Runs Scored, dtype: bool

# %%
# find no of 500's and 1000's total scored by kohli..

kohli[kohli > 500].size
# Out:
# 6

# %%
subscribe[subscribe > 200].size
# Out:
# 84

# %%
movies
# Out:
#               Actor  Movies Released  \
# 0  Amitabh Bachchan               11
# 1    Shah Rukh Khan               10
# 2        Aamir Khan                5
# 3       Salman Khan               11
# 4     Ranbir Kapoor               16
# 5  Deepika Padukone               15
# 6   Priyanka Chopra               12
# 7      Katrina Kaif               17
# 8        Alia Bhatt               10
# 9    Hrithik Roshan               18
#
#    Average Box Office Collection (in Crores)  Awards Won  Hit Movies  \
# 0                                       3080           7           9
# 1                                       4430           2           4
# 2                                       4220           8           2
# 3                                       3100           4           9
# 4                                       3620           7           3
# 5                                       3220           8           3
# ...

# %%
# find actors who have done more than 10 movies released..
movies[movies['Movies Released']>10]
# Out:
#               Actor  Movies Released  \
# 0  Amitabh Bachchan               11
# 3       Salman Khan               11
# 4     Ranbir Kapoor               16
# 5  Deepika Padukone               15
# 6   Priyanka Chopra               12
# 7      Katrina Kaif               17
# 9    Hrithik Roshan               18
#
#    Average Box Office Collection (in Crores)  Awards Won  Hit Movies  \
# 0                                       3080           7           9
# 3                                       3100           4           9
# 4                                       3620           7           3
# 5                                       3220           8           3
# 6                                       2280           7           5
# 7                                       3690           4           3
# 9                                       2470           2           3
#
#   Salman Khan
# 0        3100
# 3        3100
# 4        3100
# 5        3100
# 6        3100
# ...

# %% [markdown]
# # plotting the graphs on Series

# %%
subscribe.plot()
# Out:
# <Axes: xlabel='Total Subscribers'>

# %%
movies[movies['Movies Released']>10].plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# # Some Important Series Methods

# %%
# astype
kohli.dtype
# Out:
# dtype('int64')

# %%
import sys
sys.getsizeof(kohli)
# Out:
# 492

# %%
sys.getsizeof(kohli.astype('int16'))
# Out:
# 432

# %%
# between 

kohli[kohli.between(500, 999)].size
# Out:
# 6

# %%
# clip

subscribe
# Out:
# Total Subscribers
# 10181    181
# 10422    241
# 10708    286
# 10864    156
# 11318    454
#         ...
# 40208    422
# 40560    352
# 40756    196
# 41126    370
# 41394    268
# Name: Subscribers Gained, Length: 100, dtype: int64

# %%
subscribe.clip(100, 200)
# Out:
# Total Subscribers
# 10181    181
# 10422    200
# 10708    200
# 10864    156
# 11318    200
#         ...
# 40208    200
# 40560    200
# 40756    196
# 41126    200
# 41394    200
# Name: Subscribers Gained, Length: 100, dtype: int64

# %%
# drop_duplicates

temp = pd.Series([11,11,2,2,3,4,5,6])
temp
# Out:
# 0    11
# 1    11
# 2     2
# 3     2
# 4     3
# 5     4
# 6     5
# 7     6
# dtype: int64

# %%
temp.drop_duplicates()
# Out:
# 0    11
# 2     2
# 4     3
# 5     4
# 6     5
# 7     6
# dtype: int64

# %%
temp.drop_duplicates(keep='last')
# Out:
# 1    11
# 3     2
# 4     3
# 5     4
# 6     5
# 7     6
# dtype: int64

# %%
movies.duplicated().sum()
# Out:
# 0

# %%
temp = pd.Series([1,2,3,np.nan,5,6,np.nan,8,np.nan,10])
temp
# Out:
# 0     1.0
# 1     2.0
# 2     3.0
# 3     NaN
# 4     5.0
# 5     6.0
# 6     NaN
# 7     8.0
# 8     NaN
# 9    10.0
# dtype: float64

# %%
temp.size
# Out:
# 10

# %%
temp.count()
# Out:
# 7

# %%
# is null

kohli.isnull().sum()
# Out:
# 0

# %%
temp.isnull().sum()
# Out:
# 3

# %%
# dropna()
temp.dropna()
# Out:
# 0     1.0
# 1     2.0
# 2     3.0
# 4     5.0
# 5     6.0
# 7     8.0
# 9    10.0
# dtype: float64

# %%
# fillna

temp.fillna(temp.mean())
# Out:
# 0     1.0
# 1     2.0
# 2     3.0
# 3     5.0
# 4     5.0
# 5     6.0
# 6     5.0
# 7     8.0
# 8     5.0
# 9    10.0
# dtype: float64

# %%
kohli[kohli.isin([400, 441])]
# Out:
# Series([], Name: Runs Scored, dtype: int64)

# %%
# apply 
movies
# Out:
#               Actor  Movies Released  \
# 0  Amitabh Bachchan               11
# 1    Shah Rukh Khan               10
# 2        Aamir Khan                5
# 3       Salman Khan               11
# 4     Ranbir Kapoor               16
# 5  Deepika Padukone               15
# 6   Priyanka Chopra               12
# 7      Katrina Kaif               17
# 8        Alia Bhatt               10
# 9    Hrithik Roshan               18
#
#    Average Box Office Collection (in Crores)  Awards Won  Hit Movies  \
# 0                                       3080           7           9
# 1                                       4430           2           4
# 2                                       4220           8           2
# 3                                       3100           4           9
# 4                                       3620           7           3
# 5                                       3220           8           3
# ...

# %%
subscribe.apply(lambda x: 'good day' if x > subscribe.mean() else 'bad day')
# Out:
# Total Subscribers
# 10181     bad day
# 10422     bad day
# 10708     bad day
# 10864     bad day
# 11318    good day
#            ...
# 40208    good day
# 40560    good day
# 40756     bad day
# 41126    good day
# 41394     bad day
# Name: Subscribers Gained, Length: 100, dtype: object

# %% [markdown]
# Creating DataFrame

# %%
import numpy as np
import pandas as pd

# %%
# using lists

student_data = [[100, 80, 10], 
                [90,0,87],
                [120,110,10],
                [80,2,40]]

pd.DataFrame(student_data, columns=['id', 'marks','pacakage'])
# Out:
#     id  marks  pacakage
# 0  100     80        10
# 1   90      0        87
# 2  120    110        10
# 3   80      2        40

# %%
# using dict :

student_dict = {
    'id ' : [100, 80, 10, 11],
    'marks' : [80,80,70,90],
    'package' : [10, 7, 14, 2]
}

students = pd.DataFrame(student_dict)
students
# Out:
#    id   marks  package
# 0  100     80       10
# 1   80     80        7
# 2   10     70       14
# 3   11     90        2

# %%
# using read_csv

movies = pd.read_excel('bollywood_fake_dataset.xlsx')
movies.head(2)
# Out:
#               Actor  Movies Released  \
# 0  Amitabh Bachchan               11
# 1    Shah Rukh Khan               10
#
#    Average Box Office Collection (in Crores)  Awards Won  Hit Movies
# 0                                       3080           7           9
# 1                                       4430           2           4

# %% [markdown]
# # read the ipl matches datasets

# %%
ipl = pd.read_csv('IPL_Matches_2008_2022.csv')
ipl
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
# valus_count(series and dataframe)

marks_series
# Out:
# a    10
# b    20
# c    30
# Name: Nitish ke marks, dtype: int64

# %%
marks
# Out:
# A    67
# B     6
# C     8
# D    78
# E    99
# Name: nitish kr marks, dtype: int64

# %%
marks = pd.DataFrame([[100, 80, 10], 
                [90,0,87],
                [120,110,10],
                [80,2,40],
                [80, 2, 40]
            ], columns=['id', 'marks','pacakage'])

# %%
type(marks)
# Out:
# pandas.core.frame.DataFrame

# %%
# values count
marks.value_counts()
# Out:
# id   marks  pacakage
# 80   2      40          2
# 90   0      87          1
# 100  80     10          1
# 120  110    10          1
# Name: count, dtype: int64

# %%
ipl = pd.read_csv('IPL_Matches_2008_2022.csv')

# %%
# find which  player has won most potm -> in finals and qualifiers

# %%
ipl[~ipl['MatchNumber'].str.isdigit()]['Player_of_Match'].value_counts()
# Out:
# Player_of_Match
# KA Pollard           3
# F du Plessis         3
# SK Raina             3
# A Kumble             2
# MK Pandey            2
# YK Pathan            2
# M Vijay              2
# JJ Bumrah            2
# AB de Villiers       2
# SR Watson            2
# HH Pandya            1
# Harbhajan Singh      1
# A Nehra              1
# V Sehwag             1
# UT Yadav             1
# MS Bisla             1
# BJ Hodge             1
# MEK Hussey           1
# MS Dhoni             1
# CH Gayle             1
# MM Patel             1
# DE Bollinger         1
# AC Gilchrist         1
# RG Sharma            1
# DA Warner            1
# MC Henriques         1
# JC Buttler           1
# RM Patidar           1
# DA Miller            1
# VR Iyer              1
# SP Narine            1
# RD Gaikwad           1
# TA Boult             1
# MP Stoinis           1
# KS Williamson        1
# RR Pant              1
# SA Yadav             1
# Rashid Khan          1
# AD Russell           1
# ...

# %%
# toss decisison plot

ipl['TossDecision'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
# how many matches each item has played

# %%
students = pd.DataFrame({
    'name': ['nitish','ankit','rupesh',np.nan, 'mrityunjay' ,np.nan,'rishabh',np.nan, 'aditya',np.nan],
    'college' : [ 'bit','iit','vit', np.nan, np.nan, 'vlsi' ,'ssit' ,np. nan, np.nan, 'git'],
    'branch' : ['eee', 'it','cse',np.nan, 'me', 'ce', 'civ','cse', 'bio' ,np.nan],
    'cgpa' : [6.66,8.25,6.41, np. nan, 5.6,9.0,7.4,10,7.4,np.nan], 'package' : [4,5,6,np.nan, 6,7,8,9,np.nan, np.nan]
})

# %%
students
# Out:
#          name college branch   cgpa  package
# 0      nitish     bit    eee   6.66      4.0
# 1       ankit     iit     it   8.25      5.0
# 2      rupesh     vit    cse   6.41      6.0
# 3         NaN     NaN    NaN    NaN      NaN
# 4  mrityunjay     NaN     me   5.60      6.0
# 5         NaN    vlsi     ce   9.00      7.0
# 6     rishabh    ssit    civ   7.40      8.0
# 7         NaN     NaN    cse  10.00      9.0
# 8      aditya     NaN    bio   7.40      NaN
# 9         NaN     git    NaN    NaN      NaN

# %%
students.sort_values('name', na_position='first', ascending=False)
# Out:
#          name college branch   cgpa  package
# 3         NaN     NaN    NaN    NaN      NaN
# 5         NaN    vlsi     ce   9.00      7.0
# 7         NaN     NaN    cse  10.00      9.0
# 9         NaN     git    NaN    NaN      NaN
# 2      rupesh     vit    cse   6.41      6.0
# 6     rishabh    ssit    civ   7.40      8.0
# 0      nitish     bit    eee   6.66      4.0
# 4  mrityunjay     NaN     me   5.60      6.0
# 1       ankit     iit     it   8.25      5.0
# 8      aditya     NaN    bio   7.40      NaN

# %%
students
# Out:
#          name college branch   cgpa  package
# 0      nitish     bit    eee   6.66      4.0
# 1       ankit     iit     it   8.25      5.0
# 2      rupesh     vit    cse   6.41      6.0
# 3         NaN     NaN    NaN    NaN      NaN
# 4  mrityunjay     NaN     me   5.60      6.0
# 5         NaN    vlsi     ce   9.00      7.0
# 6     rishabh    ssit    civ   7.40      8.0
# 7         NaN     NaN    cse  10.00      9.0
# 8      aditya     NaN    bio   7.40      NaN
# 9         NaN     git    NaN    NaN      NaN

# %%
# rank series

# %%
batsman = pd.read_csv('ipl_batsman_runs.csv')

# %%
batsman.sample(5)
# Out:
#           Batsman Team  Matches  Runs  Average  StrikeRate
# 4        KL Rahul  LSG      100  4000     40.2       138.3
# 3  Shikhar Dhawan   DC      206  6244     40.5       126.5
# 1    Rohit Sharma   MI      213  5670     32.7       130.0
# 0     Virat Kohli  RCB      192  6076     38.1       130.1
# 2    David Warner  SRH      168  5446     40.3       142.5

# %%
batsman['batting_run'] = batsman['Runs'].rank(ascending=False)

# %%
batsman.sort_values('Runs')
# Out:
#           Batsman Team  Matches  Runs  Average  StrikeRate  batting_run
# 4        KL Rahul  LSG      100  4000     40.2       138.3          5.0
# 2    David Warner  SRH      168  5446     40.3       142.5          4.0
# 1    Rohit Sharma   MI      213  5670     32.7       130.0          3.0
# 0     Virat Kohli  RCB      192  6076     38.1       130.1          2.0
# 3  Shikhar Dhawan   DC      206  6244     40.5       126.5          1.0
