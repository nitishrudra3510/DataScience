# %%
import pandas as pd
titanic_data = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
 # install pandas
pd.set_option('display.max_rows', None)
# Reset display options to the default (limit number of rows)

# %%
titanic_data # prints all data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
titanic_data.head() # print 5 rows from starting..
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic_data.tail() # print 5 rows from the last.
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
titanic_data.shape # to show the no of rows and columns
# Out:
# (891, 12)

# %%
titanic_data.describe() # provide us the statistical data
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# we can extract statistical infomration of only object data types.
titanic_data.describe(include='object')
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
# we can extract statistical infomration of only float data types.
titanic_data.describe(include='float64')
# Out:
#               Age        Fare
# count  714.000000  891.000000
# mean    29.699118   32.204208
# std     14.526497   49.693429
# min      0.420000    0.000000
# 25%     20.125000    7.910400
# 50%     28.000000   14.454200
# 75%     38.000000   31.000000
# max     80.000000  512.329200

# %%
titanic_data.info() # provides the data types of columns.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# accessing the columns directory;
titanic_data.Name
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
# 5                                       Moran, Mr. James
# 6                                McCarthy, Mr. Timothy J
# 7                         Palsson, Master. Gosta Leonard
# 8      Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                    Nasser, Mrs. Nicholas (Adele Achem)
# 10                       Sandstrom, Miss. Marguerite Rut
# 11                              Bonnell, Miss. Elizabeth
# 12                        Saundercock, Mr. William Henry
# 13                           Andersson, Mr. Anders Johan
# 14                  Vestrom, Miss. Hulda Amanda Adolfina
# 15                      Hewlett, Mrs. (Mary D Kingcome)
# ...

# %%
# # accessing the columns directory with another methods.
titanic_data['Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
# 5                                       Moran, Mr. James
# 6                                McCarthy, Mr. Timothy J
# 7                         Palsson, Master. Gosta Leonard
# 8      Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                    Nasser, Mrs. Nicholas (Adele Achem)
# 10                       Sandstrom, Miss. Marguerite Rut
# 11                              Bonnell, Miss. Elizabeth
# 12                        Saundercock, Mr. William Henry
# 13                           Andersson, Mr. Anders Johan
# 14                  Vestrom, Miss. Hulda Amanda Adolfina
# 15                      Hewlett, Mrs. (Mary D Kingcome)
# ...

# %% [markdown]
# # Data Cleaning.

# %%
titanic_data.isnull().sum() # give the sum of nulls of each columns..
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# # find the mean to fill the mean values in the Age column on the Nan values.

# %%
avg_age = titanic_data['Age'].mean() # here it use mean because here it not extreme difference in the ages.
avg_age
# Out:
# 29.69911764705882

# %% [markdown]
# # fill the values of Nan values.

# %% [markdown]
# 1. fill the values with avg_age

# %%
titanic_data['Age']=titanic_data.Age.fillna(avg_age)

# %%
titanic_data['Age'].isnull().sum()  # now it is showing no any values.
# Out:
# 0

# %% [markdown]
# 2. Fill with mode
#
# mode_age = titanic_data['Age'].mode()[0]  # mode() returns a Series, take the first value
# titanic_data['Age'] = titanic_data['Age'].fillna(mode_age)
#
#
# 3. Forward fill(ffill): You can use the last known value to fill the NaN. This method is useful in time series data.
#
# titanic_data['Age'] = titanic_data['Age'].fillna(method='ffill')
#
#
# 4. Backward Fill (bfill)
#
# This method fills NaN values with the next known value.
#
# titanic_data['Age'] = titanic_data['Age'].fillna(method='bfill')

# %%
# 2.
mode_age = titanic_data['Age'].mode()[0]  # mode() returns a Series, take the first value
titanic_data['Age'] = titanic_data['Age'].fillna(mode_age)

# %%
titanic_data['Age'].isnull().sum()
# Out:
# 0

# %% [markdown]
# # now for categorical data missing

# %%
# Fill the values in the Cabin:

titanic_data['Cabin'].isnull().sum() # count of null values
# Out:
# 0

# %%
titanic_data['Cabin'].nunique() # count values  of unique values of cabin columns
# Out:
# count         204
# unique        147
# top       B96 B98
# freq            4
# Name: Cabin, dtype: object

# %%
titanic_data['Cabin'].describe() # shows 204 non-null entries with 147 unique cabin identifiers, where 'B96 B98' is the most frequent (4 occurrences).
# Out:
# count         204
# unique        147
# top       B96 B98
# freq            4
# Name: Cabin, dtype: object

# %% [markdown]
# fill values with Placehonlders.

# %%
titanic_data['Cabin']=titanic_data['Cabin'].fillna('unknown')

# %%
titanic_data['Cabin']
# Out:
# 0              unknown
# 1                  C85
# 2              unknown
# 3                 C123
# 4              unknown
# 5              unknown
# 6                  E46
# 7              unknown
# 8              unknown
# 9              unknown
# 10                  G6
# 11                C103
# 12             unknown
# 13             unknown
# 14             unknown
# 15             unknown
# 16             unknown
# 17             unknown
# 18             unknown
# 19             unknown
# 20             unknown
# 21                 D56
# 22             unknown
# 23                  A6
# 24             unknown
# 25             unknown
# 26             unknown
# 27         C23 C25 C27
# 28             unknown
# 29             unknown
# 30             unknown
# 31                 B78
# 32             unknown
# 33             unknown
# 34             unknown
# 35             unknown
# 36             unknown
# 37             unknown
# 38             unknown
# 39             unknown
# ...

# %% [markdown]
# # fill with mode

# %% [markdown]
# if we want fill the another values of Nan but
#
# I have already fill the unknown values on the NaN values.
#
# so, first we replace the values then fill any another np.nan values

# %%
import numpy as np

# Replace "Unknown" back to NaN
titanic_data['Cabin'] = titanic_data['Cabin'].replace("unknown", np.nan)

# %%
titanic_data['Cabin']
# Out:
# 0                  NaN
# 1                  C85
# 2                  NaN
# 3                 C123
# 4                  NaN
# 5                  NaN
# 6                  E46
# 7                  NaN
# 8                  NaN
# 9                  NaN
# 10                  G6
# 11                C103
# 12                 NaN
# 13                 NaN
# 14                 NaN
# 15                 NaN
# 16                 NaN
# 17                 NaN
# 18                 NaN
# 19                 NaN
# 20                 NaN
# 21                 D56
# 22                 NaN
# 23                  A6
# 24                 NaN
# 25                 NaN
# 26                 NaN
# 27         C23 C25 C27
# 28                 NaN
# 29                 NaN
# 30                 NaN
# 31                 B78
# 32                 NaN
# 33                 NaN
# 34                 NaN
# 35                 NaN
# 36                 NaN
# 37                 NaN
# 38                 NaN
# 39                 NaN
# ...

# %%
mode_cabin = titanic_data.Cabin.mode()[0] # mode()[0] means values that appear most frequently in the datasets.
titanic_data['Cabin'] = titanic_data.Cabin.fillna(mode_cabin)

# %%
titanic_data['Cabin']
# Out:
# 0              B96 B98
# 1                  C85
# 2              B96 B98
# 3                 C123
# 4              B96 B98
# 5              B96 B98
# 6                  E46
# 7              B96 B98
# 8              B96 B98
# 9              B96 B98
# 10                  G6
# 11                C103
# 12             B96 B98
# 13             B96 B98
# 14             B96 B98
# 15             B96 B98
# 16             B96 B98
# 17             B96 B98
# 18             B96 B98
# 19             B96 B98
# 20             B96 B98
# 21                 D56
# 22             B96 B98
# 23                  A6
# 24             B96 B98
# 25             B96 B98
# 26             B96 B98
# 27         C23 C25 C27
# 28             B96 B98
# 29             B96 B98
# 30             B96 B98
# 31                 B78
# 32             B96 B98
# 33             B96 B98
# 34             B96 B98
# 35             B96 B98
# 36             B96 B98
# 37             B96 B98
# 38             B96 B98
# 39             B96 B98
# ...

# %% [markdown]
# mode()[1] retrieves the second most frequently occurring value from the mode of a Series or DataFrame, if it exists.

# %%
titanic_data['Embarked'].isnull().sum()
# Out:
# 2

# %%
titanic_data['Embarked'].describe()
# Out:
# count     889
# unique      3
# top         S
# freq      644
# Name: Embarked, dtype: object

# %% [markdown]
# # now we can go for mode or drop the data,  I would be prefered dropping the the unneccsary values(NaN Values) but if we will drop then the lost the data. So, prevent the data that we can use subset.

# %% [markdown]
# subset :

# %%
# Drop rows where the 'Cabin' column has NaN values
titanic_data.dropna(subset=['Cabin'], inplace=True) 

#dropna(subset=['Cabin']) removes only the where the cabin columns has NaN values, without affecting other columns..

# %%
mode_Embarked = titanic_data.Embarked.mode()[0]
titanic_data['Embarked'] = titanic_data['Embarked'].fillna(mode)

# %%
# give the 0 null values;
titanic_data['Embarked'].isna().sum() # .isna() same as isnull()
# Out:
# 0

# %%
titanic_data.nunique(axis=1) # columns wise
# Out:
# 0       9
# 1      10
# 2       9
# 3      10
# 4       9
# 5       8
# 6      10
# 7      10
# 8      11
# 9      10
# 10     10
# 11     10
# 12      9
# 13     11
# 14      9
# 15      9
# 16     11
# 17      9
# 18     10
# 19      9
# 20      9
# 21     11
# 22     10
# 23     10
# 24     10
# 25     10
# 26      8
# 27     12
# 28      9
# 29      8
# 30      9
# 31      9
# 32      9
# 33      9
# 34      9
# 35      9
# 36      9
# 37      9
# 38      9
# 39     10
# 40     10
# 41     10
# 42      8
# 43      9
# 44     10
# 45      8
# 46      9
# 47      9
# 48      9
# 49     10
# 50     11
# 51      9
# 52     10
# 53     10
# 54     10
# 55      9
# 56     10
# 57      9
# 58      9
# 59     11
# 60      9
# 61      9
# 62     10
# 63     10
# 64      8
# 65      8
# 66     11
# 67      9
# 68     11
# 69     10
# 70      9
# 71     11
# 72      9
# 73     10
# 74     10
# 75     10
# 76      8
# 77      8
# 78     10
# 79     10
# 80      9
# 81     10
# 82      9
# ...

# %%
titanic_data.nunique(axis=0) # row wise and also it take by defaults..
# Out:
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             88
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# Cabin          147
# Embarked         3
# dtype: int64

# %%
# Find the count of unique values from each column
titanic_data['Pclass'].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
titanic_data['Pclass'].value_counts().head()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
titanic_data.value_counts(sort=False)
# Out:
# PassengerId  Survived  Pclass  Name                                                                                Sex     Age    SibSp  Parch  Ticket             Fare      Cabin            Embarked
# 2            1         1       Cumings, Mrs. John Bradley (Florence Briggs Thayer)                                 female  38.00  1      0      PC 17599           71.2833   C85              C           1
# 4            1         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)                                        female  35.00  1      0      113803             53.1000   C123             S           1
# 7            0         1       McCarthy, Mr. Timothy J                                                             male    54.00  0      0      17463              51.8625   E46              S           1
# ...

# %%
titanic_data.value_counts(dropna=False)
# Out:
# PassengerId  Survived  Pclass  Name                                                                                Sex     Age        SibSp  Parch  Ticket              Fare      Cabin            Embarked
# 1            0         3       Braund, Mr. Owen Harris                                                             male    22.000000  1      0      A/5 21171           7.2500    NaN              S           1
# 599          0         3       Boulos, Mr. Hanna                                                                   male    29.699118  0      0      2664                7.2250    NaN              C           1
# 588          1         1       Frolicher-Stehli, Mr. Maxmillian                                                    male    60.000000  1      1      13567               79.2000   B41              C           1
# ...

# %%
df = pd.DataFrame({'num_legs': [2, 4, 4, 6],
                    'num_wings': [2, 0, 0, 0]},
                   index=['falcon', 'dog', 'cat', 'ant'])

# %%
df
# Out:
#         num_legs  num_wings
# falcon         2          2
# dog            4          0
# cat            4          0
# ant            6          0

# %%
df.value_counts() # no of uniques values : Explanation:

# There are two rows where num_legs is 4 and num_wings is 0 (dog and cat).
# There is one row where num_legs is 2 and num_wings is 2 (falcon).
# There is one row where num_legs is 6 and num_wings is 0 (ant).
# Out:
# num_legs  num_wings
# 4         0            2
# 2         2            1
# 6         0            1
# Name: count, dtype: int64

# %%
df.value_counts(dropna=False) # dropna : bool, default True Don't include counts of rows that contain NA values.
# Out:
# num_legs  num_wings
# 4         0            2
# 2         2            1
# 6         0            1
# Name: count, dtype: int64

# %%
df.value_counts(sort=False)
# Out:
# num_legs  num_wings
# 2         2            1
# 4         0            2
# 6         0            1
# Name: count, dtype: int64

# %%
df.value_counts(normalize=True) # sort the frequencies when it true other wise it will sort by data frames when when it is false.
# Out:
# num_legs  num_wings
# 4         0            0.50
# 2         2            0.25
# 6         0            0.25
# Name: proportion, dtype: float64

# %%
df.value_counts(ascending=True) # when it is false then it is sort ascending order other it will decreasing order
# Out:
# num_legs  num_wings
# 2         2            1
# 6         0            1
# 4         0            2
# Name: count, dtype: int64

# %% [markdown]
# # Finding statitics for each specific column

# %%
titanic_data['Name'].mode() #
#if any name appears more than once, it will be shown as the mode. If no name repeats, it will return an empty Series.
# Out:
# 0                                    Abbing, Mr. Anthony
# 1                            Abbott, Mr. Rossmore Edward
# 2                       Abbott, Mrs. Stanton (Rosa Hunt)
# 3                                    Abelson, Mr. Samuel
# 4                  Abelson, Mrs. Samuel (Hannah Wizosky)
# 5                         Adahl, Mr. Mauritz Nils Martin
# 6                                        Adams, Mr. John
# 7         Ahlin, Mrs. Johan (Johanna Persdotter Larsson)
# 8                             Aks, Mrs. Sam (Leah Rosen)
# 9                            Albimona, Mr. Nassef Cassem
# 10                                Alexander, Mr. William
# 11                           Alhomaki, Mr. Ilmari Rudolf
# 12                                        Ali, Mr. Ahmed
# 13                                      Ali, Mr. William
# 14                         Allen, Miss. Elisabeth Walton
# 15                              Allen, Mr. William Henry
# ...

# %%
titanic_data.mode(numeric_only=False)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0     3.0
# 1              2       NaN     NaN
# 2              3       NaN     NaN
# 3              4       NaN     NaN
# 4              5       NaN     NaN
# 5              6       NaN     NaN
# 6              7       NaN     NaN
# 7              8       NaN     NaN
# 8              9       NaN     NaN
# 9             10       NaN     NaN
# 10            11       NaN     NaN
# 11            12       NaN     NaN
# 12            13       NaN     NaN
# 13            14       NaN     NaN
# 14            15       NaN     NaN
# 15            16       NaN     NaN
# 16            17       NaN     NaN
# 17            18       NaN     NaN
# 18            19       NaN     NaN
# 19            20       NaN     NaN
# 20            21       NaN     NaN
# 21            22       NaN     NaN
# 22            23       NaN     NaN
# 23            24       NaN     NaN
# 24            25       NaN     NaN
# ...

# %%
import numpy as np

# %%
df = pd.DataFrame([('bird', 2, 2),
...                    ('mammal', 4, np.nan),
...                    ('arthropod', 8, 0),
...                    ('bird', 2, np.nan)],
...                   index=('falcon', 'horse', 'spider', 'ostrich'),columns=('species', 'legs', 'wings'))

# %%
df
# Out:
#            species  legs  wings
# falcon        bird     2    2.0
# horse       mammal     4    NaN
# spider   arthropod     8    0.0
# ostrich       bird     2    NaN

# %%
# How the mode is calculated:
# species:
# The values are: ['bird', 'mammal', 'arthropod', 'bird']
# The most frequent value is 'bird' (appears twice).
# So, 'bird' is the mode for this column.
# legs:
# The values are: [2, 4, 8, 2]
# The most frequent value is 2 (appears twice).
# So, 2 is the mode for this column.
# wings:
# The values are: [2, NaN, 0, NaN]
# The most frequent value is 2 (appears once, but no other value appears more often).
# There’s also a 0, which appears once as well. Since mode() can return multiple modes, you get both 0 and 2 as modes for this column.

# %%
df.mode()
# Out:
#   species  legs  wings
# 0    bird   2.0    0.0
# 1     NaN   NaN    2.0

# %%
df.mode(axis=1)
# Out:
# /var/folders/kq/d8w7gp1d5dn0q7qm6tzkh4pc0000gn/T/ipykernel_78348/1210916842.py:1: UserWarning: Unable to sort modes: '<' not supported between instances of 'int' and 'str'
#   df.mode(axis=1)
#                  0    1    2
# falcon           2  NaN  NaN
# horse       mammal  4.0  NaN
# spider   arthropod  8.0  0.0
# ostrich       bird  2.0  NaN

# %%
df.mode(numeric_only = True)
# Out:
#    legs  wings
# 0   2.0    0.0
# 1   NaN    2.0

# %%
df.mode(dropna=False) # it is true: then the not consider of Nan/Nat.
# Out:
#   species  legs  wings
# 0    bird   2.0    0.0
# 1     NaN   NaN    2.0

# %% [markdown]
# # The mean() function calculates the average of a column by summing up all the values and dividing by the total number of valid (non-missing) values.
#
# Here's how it's calculated for titanic_data['Fare']:
#
# Sum of the values:
# The function adds up all the values in the Fare column.
#
# Exclude missing values (NaN):
# Any missing (NaN) values in the Fare column are automatically ignored.
#
# Count of non-missing values:
# It counts how many valid (non-NaN) entries there are in the Fare column.
#
# Divide the sum by the count:
# The sum of all fares is divided by the count of non-missing entries to get the average fare.
#
# Formula:
# Mean =
# Sum of all fares/Number of non-NaN entries in the Fare column
#
# ​
#
# In pandas, titanic_data['Fare'].mean() performs this entire calculation automatically.

# %%
titanic_data['Fare'].mean(numeric_only=False)
# Out:
# 32.204207968574636

# %% [markdown]
# # Selecting Rows and Columns

# %% [markdown]
# selecting multiple columns at a time :

# %%
titanic_data[['Name', 'Fare', 'Sex']] # if you want to select one columns then in single square brl [] and for the multiple columns then '[[]]'
# Out:
#                                                   Name      Fare     Sex
# 0                              Braund, Mr. Owen Harris    7.2500    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...   71.2833  female
# 2                               Heikkinen, Miss. Laina    7.9250  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)   53.1000  female
# 4                             Allen, Mr. William Henry    8.0500    male
# 5                                     Moran, Mr. James    8.4583    male
# 6                              McCarthy, Mr. Timothy J   51.8625    male
# 7                       Palsson, Master. Gosta Leonard   21.0750    male
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)   11.1333  female
# 9                  Nasser, Mrs. Nicholas (Adele Achem)   30.0708  female
# 10                     Sandstrom, Miss. Marguerite Rut   16.7000  female
# 11                            Bonnell, Miss. Elizabeth   26.5500  female
# ...

# %%
titanic_data.loc[0:5, ["Name", "Fare"]] # .loc[] is used to select rows and columns based on their labels.
# Out:
#                                                 Name     Fare
# 0                            Braund, Mr. Owen Harris   7.2500
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  71.2833
# 2                             Heikkinen, Miss. Laina   7.9250
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  53.1000
# 4                           Allen, Mr. William Henry   8.0500
# 5                                   Moran, Mr. James   8.4583

# %%
df = pd.DataFrame([[1, 2], [4, 5], [7, 8]],
...                   index=['cobra', 'viper', 'sidewinder'],
...                   columns=['max_speed', 'shield'])

# %%
df
# Out:
#             max_speed  shield
# cobra               1       2
# viper               4       5
# sidewinder          7       8

# %%
df.loc['cobra','shield'] # it gives only one value where the match of row and columns
# Out:
# 2

# %%
df.loc['cobra':'sidewinder','shield'] # it give the values of the shield columns.
# Out:
# cobra         2
# viper         5
# sidewinder    8
# Name: shield, dtype: int64

# %%
df.loc['cobra':'viper','max_speed'] # it give the values of the max_speed columns upto row = viper.
# Out:
# cobra    1
# viper    4
# Name: max_speed, dtype: int64

# %%
df.loc['cobra' : "sidewinder"]
# Out:
# Empty DataFrame
# Columns: [Scores]
# Index: []

# %%
df.loc[:, 'max_speed'] = 30

# %%
df
# Out:
#    Scores  max_speed
# 0      80         30
# 1      85         30
# 2      90         30
# 3      95         30
# 4     100         30
# 5     300         30

# %%
df.loc[df["Scores"]>35]
# Out:
#    Scores  max_speed
# 0      80         30
# 1      85         30
# 2      90         30
# 3      95         30
# 4     100         30
# 5     300         30

# %%
df.loc[pd.Series([True, False, True], index=["cobra","viper","sidewinder"])] # those rows has true in the series, it will select, whose are "cobra" and "sidwinder".
# Out:
#             max_speed  shield
# cobra               1       2
# sidewinder          7       8

# %% [markdown]
# # loc : it is used for only category data(object, float, etc)..

# %%
titanic_data.loc[10, :] # selecting row no 10 and get the all values of columns.
# Out:
# PassengerId                                 11
# Survived                                     1
# Pclass                                       3
# Name           Sandstrom, Miss. Marguerite Rut
# Sex                                     female
# Age                                        4.0
# SibSp                                        1
# Parch                                        1
# Ticket                                 PP 9549
# Fare                                      16.7
# Cabin                                       G6
# Embarked                                     S
# Name: 10, dtype: object

# %%
titanic_data.loc[:, "Fare"] # selecting all rows and one specific columns ("Fare") same sa titanic_data["Fare"]
# Out:
# 0        7.2500
# 1       71.2833
# 2        7.9250
# 3       53.1000
# 4        8.0500
# 5        8.4583
# 6       51.8625
# 7       21.0750
# 8       11.1333
# 9       30.0708
# 10      16.7000
# 11      26.5500
# 12       8.0500
# 13      31.2750
# 14       7.8542
# 15      16.0000
# 16      29.1250
# 17      13.0000
# 18      18.0000
# 19       7.2250
# 20      26.0000
# 21      13.0000
# 22       8.0292
# 23      35.5000
# 24      21.0750
# 25      31.3875
# 26       7.2250
# 27     263.0000
# 28       7.8792
# 29       7.8958
# 30      27.7208
# 31     146.5208
# 32       7.7500
# 33      10.5000
# 34      82.1708
# 35      52.0000
# 36       7.2292
# 37       8.0500
# 38      18.0000
# 39      11.2417
# 40       9.4750
# 41      21.0000
# 42       7.8958
# 43      41.5792
# 44       7.8792
# 45       8.0500
# 46      15.5000
# 47       7.7500
# 48      21.6792
# 49      17.8000
# 50      39.6875
# 51       7.8000
# 52      76.7292
# 53      26.0000
# 54      61.9792
# ...

# %%
titanic_data.loc[titanic_data['Fare']>50]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 27            28         0       1
# 31            32         1       1
# 34            35         0       1
# 35            36         0       1
# 52            53         1       1
# 54            55         0       1
# 61            62         1       1
# 62            63         0       1
# 72            73         0       2
# 74            75         1       3
# 88            89         1       1
# 92            93         0       1
# 97            98         1       1
# 102          103         0       1
# 110          111         0       1
# 118          119         0       1
# 120          121         0       2
# 124          125         0       1
# 137          138         0       1
# 139          140         0       1
# 151          152         1       1
# 155          156         0       1
# ...

# %% [markdown]
# # using iloc[] for integer based selection..

# %%
titanic_data.iloc[1:10, 0:3] # [rows and column]
# Out:
#    PassengerId  Survived  Pclass
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2

# %% [markdown]
# # Set_index

# %%
titanic_data.set_index("Name").head(3) # this is not permanent fixed index.
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
#
#                                                     Pclass     Sex   Age  \
# Name
# Braund, Mr. Owen Harris                                  3    male  22.0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0
# Heikkinen, Miss. Laina                                   3  female  26.0
#
#                                                     SibSp  Parch  \
# Name
# Braund, Mr. Owen Harris                                 1      0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...      1      0
# Heikkinen, Miss. Laina                                  0      0
#
#                                                               Ticket     Fare  \
# Name
# ...

# %%
titanic_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare    Cabin Embarked
# 0      0         A/5 21171   7.2500  B96 B98        S
# 1      0          PC 17599  71.2833      C85        C
# 2      0  STON/O2. 3101282   7.9250  B96 B98        S
# 3      0            113803  53.1000     C123        S
# ...

# %%
# now it is permanent.
titanic_data.set_index(['Name'], inplace = True)

# %%
titanic_data.head()
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
#
#                                                     Pclass     Sex   Age  \
# Name
# Braund, Mr. Owen Harris                                  3    male  22.0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0
# Heikkinen, Miss. Laina                                   3  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             1  female  35.0
# Allen, Mr. William Henry                                 3    male  35.0
#
#                                                     SibSp  Parch  \
# ...

# %% [markdown]
# # Reset Index

# %%
titanic_data.reset_index(inplace=True)

# %%
titanic_data
# Out:
#                                                   Name  PassengerId  Survived  \
# 0                              Braund, Mr. Owen Harris            1         0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...            2         1
# 2                               Heikkinen, Miss. Laina            3         1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)            4         1
# 4                             Allen, Mr. William Henry            5         0
# 5                                     Moran, Mr. James            6         0
# 6                              McCarthy, Mr. Timothy J            7         0
# 7                       Palsson, Master. Gosta Leonard            8         0
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)            9         1
# 9                  Nasser, Mrs. Nicholas (Adele Achem)           10         1
# 10                     Sandstrom, Miss. Marguerite Rut           11         1
# ...

# %% [markdown]
# # Handling Dupliactes

# %%
titanic_data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# here, it is found any duplicate value but if i find any value then how to remove? -
#
# # Removing Duplicate Rows:
#
# titanic_data.drop_duplicates(inplace=True)
#
# # Removing Duplicates Based on Specific Columns:
#
# titanic_data.drop_duplicates(subset=['Name'], inplace=True)

# %%
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'Alice', 'David', 'Bob'],
    'Age': [25, 30, 35, 25, 40, 30],
    'City': ['New York', 'Los Angeles', 'Chicago', 'New York', 'Houston', 'Los Angeles']
}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#       Name  Age         City
# 0    Alice   25     New York
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago
# 3    Alice   25     New York
# 4    David   40      Houston
# 5      Bob   30  Los Angeles

# %% [markdown]
# 1. drop_duplicates() - Removes duplicate rows

# %%
df_no_duplicates = df.drop_duplicates()
df_no_duplicates
# Out:
#       Name  Age         City
# 0    Alice   25     New York
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago
# 4    David   40      Houston

# %% [markdown]
# 2. duplicated() - Returns a Boolean Series indicating duplicates

# %%
df_duplicates_bool = df.duplicated()
df_duplicates_bool
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5     True
# dtype: bool

# %% [markdown]
#  3. value_counts() - Counts unique values in the 'Name' column

# %%
df_value_counts = df['Name'].value_counts()
df_value_counts
# Out:
# Name
# Alice      2
# Bob        2
# Charlie    1
# David      1
# Name: count, dtype: int64

# %% [markdown]
#  4. groupby() - Group by 'Name' and count the occurrences

# %%
df_groupby_count = df.groupby(['Name']).size()
df_groupby_count
# Out:
# Name
# Alice      2
# Bob        2
# Charlie    1
# David      1
# dtype: int64

# %% [markdown]
#  5. nunique() - Counts unique values in the 'Name' column

# %%
df_nunique = df['Name'].nunique()
df_nunique
# Out:
# 4

# %%
df_no_duplicates, df_duplicates_bool, df_value_counts, df_groupby_count, df_nunique
# Out:
# (      Name  Age         City
#  0    Alice   25     New York
#  1      Bob   30  Los Angeles
#  2  Charlie   35      Chicago
#  4    David   40      Houston,
#  0    False
#  1    False
#  2    False
#  3     True
#  4    False
#  5     True
#  dtype: bool,
#  Name
#  Alice      2
#  Bob        2
#  Charlie    1
#  David      1
#  Name: count, dtype: int64,
#  Name
#  Alice      2
#  Bob        2
#  Charlie    1
#  David      1
#  dtype: int64,
#  4)

# %% [markdown]
# # String Operations
