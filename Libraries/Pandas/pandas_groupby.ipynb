# %%
import pandas as pd
import numpy as np

# Set option to display all rows

# pd.set_option('display.max_rows', None)

# %%
movies = pd.read_csv('imdb-top-1000.csv')

# %% [markdown]
# Groupby : aplly the categorical data only..

# %%
movies.head(2)
# Out:
#                Series_Title Released_Year  Runtime  Genre  IMDB_Rating  \
# 0  The Shawshank Redemption          1994      142  Drama          9.3
# 1             The Godfather          1972      175  Crime          9.2
#
#                Director          Star1  No_of_Votes        Gross  Metascore
# 0        Frank Darabont    Tim Robbins      2343110   28341469.0       80.0
# 1  Francis Ford Coppola  Marlon Brando      1620367  134966411.0      100.0

# %% [markdown]
# it will divide gropuby..

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
genres = movies.groupby('Genre')
genres

# %%
# apply the builting aggregation functions on groupby objects..

genres.sum()
# Out:
#                                                 Series_Title  \
# Genre
# Action     The Dark KnightThe Lord of the Rings: The Retu...
# Adventure  InterstellarBack to the FutureInglourious Bast...
# Animation  Sen to Chihiro no kamikakushiThe Lion KingHota...
# Biography  Schindler's ListGoodfellasHamiltonThe Intoucha...
# Comedy     GisaengchungLa vita è bellaModern TimesCity Li...
# Crime      The GodfatherThe Godfather: Part II12 Angry Me...
# Drama      The Shawshank RedemptionFight ClubForrest Gump...
# Family     E.T. the Extra-TerrestrialWilly Wonka & the Ch...
# Fantasy                Das Cabinet des Dr. CaligariNosferatu
# Film-Noir   The Third ManThe Maltese FalconShadow of a Doubt
# Horror     PsychoAlienThe ThingThe ExorcistNight of the L...
# Mystery    MementoRear WindowVertigoShutter IslandKahaani...
# Thriller                                     Wait Until Dark
# Western    Il buono, il brutto, il cattivoOnce Upon a Tim...
#
# ...

# %%
genres.min()
# Out:
#                               Series_Title Released_Year  Runtime  \
# Genre
# Action                                 300          1924       45
# Adventure            2001: A Space Odyssey          1925       88
# Animation                            Akira          1940       71
# Biography                 12 Years a Slave          1928       93
# Comedy                (500) Days of Summer          1921       68
# Crime                         12 Angry Men          1931       80
# Drama                                 1917          1925       64
# Family          E.T. the Extra-Terrestrial          1971      100
# Fantasy       Das Cabinet des Dr. Caligari          1920       76
# Film-Noir                Shadow of a Doubt          1941      100
# Horror                               Alien          1933       71
# Mystery                          Dark City          1938       96
# Thriller                   Wait Until Dark          1967      108
# ...

# %%
# find the top genres by total ensuring..

movies.groupby('Genre').sum()['Gross'].sort_values(ascending=False).head(5)
# Out:
# Genre
# Drama        3.540997e+10
# Action       3.263226e+10
# Comedy       1.566387e+10
# Animation    1.463147e+10
# Adventure    9.496922e+09
# Name: Gross, dtype: float64

# %% [markdown]
# this is the best.

# %%
movies.groupby('Genre')['Gross'].sum().sort_values(ascending=False).head(5)
# Out:
# Genre
# Drama        3.540997e+10
# Action       3.263226e+10
# Comedy       1.566387e+10
# Animation    1.463147e+10
# Adventure    9.496922e+09
# Name: Gross, dtype: float64

# %%
# find the genre with highest evg iDMB rating

movies.groupby('Genre')['IMDB_Rating'].mean().sort_values(ascending=False).head()
# Out:
# Genre
# Western      8.350000
# Crime        8.016822
# Fantasy      8.000000
# Mystery      7.975000
# Film-Noir    7.966667
# Name: IMDB_Rating, dtype: float64

# %%
# find the most poluar director
movies.groupby('Director')['No_of_Votes'].sum().sort_values(ascending=False).head(1)
# Out:
# Director
# Christopher Nolan    11578345
# Name: No_of_Votes, dtype: int64

# %%
# find the heghest rated movie of each genre..

# movies.groupby('Genre')['IMDB_Rating'].max()

# %%
# find the number of movies done by each actor

movies['Star1'].value_counts()
# Out:
# Star1
# Tom Hanks                    12
# Robert De Niro               11
# Al Pacino                    10
# Clint Eastwood               10
# Humphrey Bogart               9
# Leonardo DiCaprio             9
# Johnny Depp                   8
# Christian Bale                8
# James Stewart                 8
# Denzel Washington             7
# Toshirô Mifune                7
# Aamir Khan                    7
# Ethan Coen                    6
# Tom Cruise                    6
# Daniel Radcliffe              6
# Cary Grant                    6
# Charles Chaplin               6
# Jake Gyllenhaal               6
# Paul Newman                   5
# Shah Rukh Khan                5
# Dustin Hoffman                5
# Ethan Hawke                   5
# Russell Crowe                 5
# Harrison Ford                 5
# Bruce Willis                  5
# Gene Hackman                  4
# Joe Russo                     4
# William Holden                4
# Charlton Heston               4
# ...

# %% [markdown]
# these type of question to like 1. make groupby, select column, do aggregate function...

# %%
movies.groupby('Star1')['Series_Title'].count().sort_values(ascending=False)
# Out:
# Star1
# Tom Hanks                    12
# Robert De Niro               11
# Clint Eastwood               10
# Al Pacino                    10
# Leonardo DiCaprio             9
# Humphrey Bogart               9
# Johnny Depp                   8
# James Stewart                 8
# Christian Bale                8
# Toshirô Mifune                7
# Denzel Washington             7
# Aamir Khan                    7
# Charles Chaplin               6
# Cary Grant                    6
# Daniel Radcliffe              6
# Jake Gyllenhaal               6
# Tom Cruise                    6
# Ethan Coen                    6
# Paul Newman                   5
# Harrison Ford                 5
# Shah Rukh Khan                5
# Bruce Willis                  5
# Russell Crowe                 5
# Ethan Hawke                   5
# Dustin Hoffman                5
# William Holden                4
# Gene Hackman                  4
# Charlton Heston               4
# Akshay Kumar                  4
# ...

# %%
# GroupBy Attributes and Methods
# find total number of groups -> len
# find items in each group -› size
# first()/last() -> nth item
# get_group -› vs filtering
# groups
# describe
# sample
# nunique

# %%
len(movies
    .groupby('Genre'))
# Out:
# 14

# %%
movies['Genre'].nunique()
# Out:
# 14

# %%
movies.groupby('Genre').size()
# Out:
# Genre
# Action       172
# Adventure     72
# Animation     82
# Biography     88
# Comedy       155
# Crime        107
# Drama        289
# Family         2
# Fantasy        2
# Film-Noir      3
# Horror        11
# Mystery       12
# Thriller       1
# Western        4
# dtype: int64

# %%
movies['Genre'].nunique()
# Out:
# 14

# %%
genres = movies.groupby('Genre')

# first movies 
# genres.first()
# genres.last()
genres.nth(6)
# Out:
#                                        Series_Title Released_Year  Runtime  \
# 16   Star Wars: Episode V - The Empire Strikes Back          1980      124
# 27                                            Se7en          1995      127
# 32                            It's a Wonderful Life          1946      130
# 66                                           WALL·E          2008       98
# 83                               The Great Dictator          1940      125
# 102                                      Braveheart          1995      178
# 118                              North by Northwest          1959      136
# 420                                          Sleuth          1972      138
# 724                                         Get Out          2017      104
#
#          Genre  IMDB_Rating              Director             Star1  \
# 16      Action          8.7        Irvin Kershner       Mark Hamill
# 27       Crime          8.6         David Fincher    Morgan Freeman
# ...

# %%
# get_score:
# genres.get_group('Horror')
genres.get_group('Fantasy')
# Out:
#                      Series_Title Released_Year  Runtime    Genre  \
# 321  Das Cabinet des Dr. Caligari          1920       76  Fantasy
# 568                     Nosferatu          1922       94  Fantasy
#
#      IMDB_Rating      Director          Star1  No_of_Votes        Gross  \
# 321          8.1  Robert Wiene  Werner Krauss        57428  337574718.0
# 568          7.9   F.W. Murnau    Max Schreck        88794  445151978.0
#
#      Metascore
# 321        NaN
# 568        NaN

# %%
movies[movies['Genre']=='Horror']
# Out:
#                  Series_Title Released_Year  Runtime   Genre  IMDB_Rating  \
# 49                     Psycho          1960      109  Horror          8.5
# 75                      Alien          1979      117  Horror          8.4
# 271                 The Thing          1982      109  Horror          8.1
# 419              The Exorcist          1973      122  Horror          8.0
# 544  Night of the Living Dead          1968       96  Horror          7.9
# 707             The Innocents          1961      100  Horror          7.8
# 724                   Get Out          2017      104  Horror          7.7
# 844                 Halloween          1978       91  Horror          7.7
# 876         The Invisible Man          1933       71  Horror          7.7
# 932                       Saw          2004      103  Horror          7.6
# 948                The Others          2001      101  Horror          7.6
#
#                Director             Star1  No_of_Votes        Gross  Metascore
# ...

# %% [markdown]
# # show the index of the groups

# %%
genres.groups
# Out:
# {'Action': [2, 5, 8, 10, 13, 14, 16, 29, 30, 31, 39, 42, 44, 55, 57, 59, 60, 63, 68, 72, 106, 109, 129, 130, 134, 140, 142, 144, 152, 155, 160, 161, 166, 168, 171, 172, 177, 181, 194, 201, 202, 216, 217, 223, 224, 236, 241, 262, 275, 294, 308, 320, 325, 326, 331, 337, 339, 340, 343, 345, 348, 351, 353, 356, 357, 362, 368, 369, 375, 376, 390, 410, 431, 436, 473, 477, 479, 482, 488, 493, 496, 502, 507, 511, 532, 535, 540, 543, 564, 569, 570, 573, 577, 582, 583, 602, 605, 608, 615, 623, ...], 'Adventure': [21, 47, 93, 110, 114, 116, 118, 137, 178, 179, 191, 193, 209, 226, 231, 247, 267, 273, 281, 300, 301, 304, 306, 323, 329, 361, 366, 377, 402, 406, 415, 426, 458, 470, 497, 498, 506, 513, 514, 537, 549, 552, 553, 566, 576, 604, 609, 618, 638, 647, 675, 681, 686, 692, 711, 713, 739, 755, 781, 797, 798, 851, 873, 884, 912, 919, 947, 957, 964, 966, 984, 991], 'Animation': [23, 43, 46, 56, 58, 61, 66, 70, 101, 135, 146, 151, 158, 170, 197, 205, 211, 213, 219, 229, 230, 242, 245, 246, 270, 
# ...

# %%
# describe : har group ke har numberic group ko acche se calculate karke output deta hai..
genres.describe()
# Out:
#           Runtime                                                              \
#             count        mean        std    min     25%    50%     75%    max
# Genre
# Action      172.0  129.046512  28.500706   45.0  110.75  127.5  143.25  321.0
# Adventure    72.0  134.111111  33.317320   88.0  109.00  127.0  149.00  228.0
# Animation    82.0   99.585366  14.530471   71.0   90.00   99.5  106.75  137.0
# Biography    88.0  136.022727  25.514466   93.0  120.00  129.0  146.25  209.0
# Comedy      155.0  112.129032  22.946213   68.0   96.00  106.0  124.50  188.0
# Crime       107.0  126.392523  27.689231   80.0  106.50  122.0  141.50  229.0
# Drama       289.0  124.737024  27.740490   64.0  105.00  121.0  137.00  242.0
# Family        2.0  107.500000  10.606602  100.0  103.75  107.5  111.25  115.0
# Fantasy       2.0   85.000000  12.727922   76.0   80.50   85.0   89.50   94.0
# Film-Noir     3.0  104.000000   4.000000  100.0  102.00  104.0  106.00  108.0
# ...

# %% [markdown]
# # sample : here give the 2 movies name for each genre groups like action ka 2 , adventure ka 2..

# %%
genres.sample(2, replace=True)
# Out:
#                                      Series_Title Released_Year  Runtime  \
# 410                                The Terminator          1984      107
# 909                                     Celda 211          2009      113
# 713                                    Stagecoach          1939       96
# 226  Harry Potter and the Deathly Hallows: Part 2          2011      130
# 651                                         Shrek          2001       90
# 761                           Toki o kakeru shôjo          2006       98
# 849                                       Serpico          1973      130
# 671                                    Awakenings          1990      121
# 316                         It Happened One Night          1934      105
# 284                                    Paper Moon          1973      102
# 103                                Reservoir Dogs          1992       99
# 639                                  Lilja 4-ever          2002      109
# ...

# %%
genres.nunique()
# Out:
#            Series_Title  Released_Year  Runtime  IMDB_Rating  Director  Star1  \
# Genre
# Action              172             61       78           15       123    121
# Adventure            72             49       58           10        59     59
# Animation            82             35       41           11        51     77
# Biography            88             44       56           13        76     72
# Comedy              155             72       70           11       113    133
# Crime               106             56       65           14        86     85
# Drama               289             83       95           14       211    250
# Family                2              2        2            1         2      2
# Fantasy               2              2        2            2         2      2
# Film-Noir             3              3        3            3         3      3
# Horror               11             11       10            8        10     11
# ...

# %% [markdown]
# aggregate method : specify kakrta hai ki konse columns par hm konse aggregate function lagta hai..

# %%
# passing dictionary..
# genres.sum() 

genres.agg(
    {
        "Runtime" : "mean",
        "IMDB_Rating"  : "mean",
        "No_of_Votes" : "sum",
        "Gross" : "sum",
        "Metascore" : "min"
        
    }
)
# Out:
#               Runtime  IMDB_Rating  No_of_Votes         Gross  Metascore
# Genre
# Action     129.046512     7.949419     72282412  3.263226e+10       33.0
# Adventure  134.111111     7.937500     22576163  9.496922e+09       41.0
# Animation   99.585366     7.930488     21978630  1.463147e+10       61.0
# Biography  136.022727     7.938636     24006844  8.276358e+09       48.0
# Comedy     112.129032     7.901290     27620327  1.566387e+10       45.0
# Crime      126.392523     8.016822     33533615  8.452632e+09       47.0
# Drama      124.737024     7.957439     61367304  3.540997e+10       28.0
# Family     107.500000     7.800000       551221  4.391106e+08       67.0
# Fantasy     85.000000     8.000000       146222  7.827267e+08        NaN
# Film-Noir  104.000000     7.966667       367215  1.259105e+08       94.0
# Horror     102.090909     7.909091      3742556  1.034649e+09       46.0
# Mystery    119.083333     7.975000      4203004  1.256417e+09       52.0
# ...

# %%
# passing list : every gcolumn ke under alag se three column bna gya hai min, amx, and sum
genres.agg(['min', 'max', 'sum'])
# Out:
#                               Series_Title  \
#                                        min
# Genre
# Action                                 300
# Adventure            2001: A Space Odyssey
# Animation                            Akira
# Biography                 12 Years a Slave
# Comedy                (500) Days of Summer
# Crime                         12 Angry Men
# Drama                                 1917
# Family          E.T. the Extra-Terrestrial
# Fantasy       Das Cabinet des Dr. Caligari
# Film-Noir                Shadow of a Doubt
# Horror                               Alien
# Mystery                          Dark City
# Thriller                   Wait Until Dark
# Western    Il buono, il brutto, il cattivo
#
#                                                 \
#                                            max
# Genre
# Action                                 Yôjinbô
# Adventure                           Zombieland
# Animation          Ôkami kodomo no Ame to Yuki
# ...

# %%
# looping in the group
for group, data in genres:
    print(data)
# Out:
#                                           Series_Title Released_Year  Runtime  \
# 2                                      The Dark Knight          2008      152
# 5        The Lord of the Rings: The Return of the King          2003      201
# 8                                            Inception          2010      148
# 10   The Lord of the Rings: The Fellowship of the Ring          2001      178
# 13               The Lord of the Rings: The Two Towers          2002      179
# 14                                          The Matrix          1999      136
# 16      Star Wars: Episode V - The Empire Strikes Back          1980      124
# 29                                           Star Wars          1977      121
# 30                                             Seppuku          1962      133
# 31                                Shichinin no samurai          1954      207
# 39                                           Gladiator          2000      155
# ...

# %%
for group, data in genres:
    print(data[data['IMDB_Rating']==data['IMDB_Rating'].max()])
# Out:
#       Series_Title Released_Year  Runtime   Genre  IMDB_Rating  \
# 2  The Dark Knight          2008      152  Action          9.0
#
#             Director           Star1  No_of_Votes        Gross  Metascore
# 2  Christopher Nolan  Christian Bale      2303232  534858444.0       84.0
#     Series_Title Released_Year  Runtime      Genre  IMDB_Rating  \
# 21  Interstellar          2014      169  Adventure          8.6
#
#              Director                Star1  No_of_Votes        Gross  \
# 21  Christopher Nolan  Matthew McConaughey      1512360  188020017.0
#
#     Metascore
# 21       74.0
#                      Series_Title Released_Year  Runtime      Genre  \
# 23  Sen to Chihiro no kamikakushi          2001      125  Animation
#
#     IMDB_Rating        Director          Star1  No_of_Votes       Gross  \
# 23          8.6  Hayao Miyazaki  Daveigh Chase       651376  10055859.0
#
#     Metascore
# 23       96.0
# ...

# %% [markdown]
# add the highest rated movies value in the dataframe

# %%
df = pd.DataFrame(columns=movies.columns)

for group, data in genres:
    max_rating_data = data[data['IMDB_Rating'] == data['IMDB_Rating'].max()]
    df = pd.concat([df, max_rating_data], ignore_index=True)
# Out:
# /var/folders/kq/d8w7gp1d5dn0q7qm6tzkh4pc0000gn/T/ipykernel_55172/3083827188.py:5: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, max_rating_data], ignore_index=True)

# %%
df
# Out:
#                            Series_Title Released_Year Runtime      Genre  \
# 0                       The Dark Knight          2008     152     Action
# 1                          Interstellar          2014     169  Adventure
# 2         Sen to Chihiro no kamikakushi          2001     125  Animation
# 3                      Schindler's List          1993     195  Biography
# 4                          Gisaengchung          2019     132     Comedy
# 5                       La vita è bella          1997     116     Comedy
# 6                         The Godfather          1972     175      Crime
# 7              The Shawshank Redemption          1994     142      Drama
# 8            E.T. the Extra-Terrestrial          1982     115     Family
# 9   Willy Wonka & the Chocolate Factory          1971     100     Family
# 10         Das Cabinet des Dr. Caligari          1920      76    Fantasy
# 11                        The Third Man          1949     104  Film-Noir
# ...

# %%
# split(apply) combine
# apply -> builtin function

# %% [markdown]
# give the min value of eaxh columns.

# %%
genres.apply(min).head(2)
# Out:
# /var/folders/kq/d8w7gp1d5dn0q7qm6tzkh4pc0000gn/T/ipykernel_55172/2267366310.py:1: FutureWarning: The provided callable <built-in function min> is currently using np.minimum.reduce. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string np.minimum.reduce instead.
#   genres.apply(min).head(2)
# /var/folders/kq/d8w7gp1d5dn0q7qm6tzkh4pc0000gn/T/ipykernel_55172/2267366310.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   genres.apply(min).head(2)
#                     Series_Title Released_Year  Runtime      Genre  \
# Genre
# Action                       300          1924       45     Action
# ...

# %%
# find the number of movies starting with with A for each group..

def foo(group):
    print(type(group))
    return group

# %%
genres.apply(foo)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# /var/folders/kq/d8w7gp1d5dn0q7qm6tzkh4pc0000gn/T/ipykernel_55172/2904676014.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
# ...

# %% [markdown]
# # ans :

# %%
def foo(group):
    return group['Series_Title'].str.startswith("A").sum()

# %%
genres.apply(foo)
# Out:
# /var/folders/kq/d8w7gp1d5dn0q7qm6tzkh4pc0000gn/T/ipykernel_55172/2904676014.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   genres.apply(foo)
# Genre
# Action       10
# Adventure     2
# Animation     2
# Biography     9
# Comedy       14
# Crime         4
# Drama        21
# Family        0
# Fantasy       0
# Film-Noir     0
# Horror        1
# Mystery       0
# Thriller      0
# Western       0
# dtype: int64

# %%
# find ranking of each movie in the group according to IMDB score..

# %%
def rank_movie(group):
    group['genres_rank'] =  genres['IMDB_Rating'].rank(ascending=False)
    return group

# %%
# find normalized IMDBB rating group wise

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def normal(group):
    group['norm_rating'] = ((group["IMDB_Rating"] - group['IMDB_Rating'].min())/(group["IMDB_Rating"].max() - group['IMDB_Rating'].min()))
    return group
genres.apply(normal)
# Out:
# /var/folders/kq/d8w7gp1d5dn0q7qm6tzkh4pc0000gn/T/ipykernel_55172/3446149787.py:4: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   genres.apply(normal)
#                                                     Series_Title  \
# Genre
# Action    2                                      The Dark Knight
#           5        The Lord of the Rings: The Return of the King
#           8                                            Inception
#           10   The Lord of the Rings: The Fellowship of the Ring
#           13               The Lord of the Rings: The Two Towers
#           14                                          The Matrix
#           16      Star Wars: Episode V - The Empire Strikes Back
# ...

# %%
# groupby on multiple columns

duo = movies.groupby(['Director', 'Star1'])
duo

# size()
duo.size()

# getgroup
duo.get_group(("Sergio Leone", "Henry Fonda"))
# Out:
#                     Series_Title Released_Year  Runtime    Genre  IMDB_Rating  \
# 48  Once Upon a Time in the West          1968      165  Western          8.5
#
#         Director        Star1  No_of_Votes      Gross  Metascore
# 48  Sergio Leone  Henry Fonda       302844  5321508.0       80.0

# %%
# Group by Director and Star1
duo = movies.groupby(['Director', 'Star1'])

# List all group keys
print(list(duo.groups.keys()))
print(duo.size())
# Out:
# [('Aamir Khan', 'Amole Gupte'), ('Aaron Sorkin', 'Eddie Redmayne'), ('Abdellatif Kechiche', 'Léa Seydoux'), ('Abhishek Chaubey', 'Shahid Kapoor'), ('Abhishek Kapoor', 'Amit Sadh'), ('Adam Elliot', 'Toni Collette'), ('Adam McKay', 'Christian Bale'), ('Aditya Chopra', 'Shah Rukh Khan'), ('Aditya Dhar', 'Vicky Kaushal'), ('Akira Kurosawa', 'Takashi Shimura'), ('Akira Kurosawa', 'Tatsuya Nakadai'), ('Akira Kurosawa', 'Toshirô Mifune'), ('Alain Resnais', 'Emmanuelle Riva'), ('Alan J. Pakula', 'Dustin Hoffman'), ('Alan Parker', 'Bob Geldof'), ('Alan Parker', 'Brad Davis'), ('Alan Parker', 'Gene Hackman'), ('Alejandro Amenábar', 'Eduardo Noriega'), ('Alejandro Amenábar', 'Javier Bardem'), ('Alejandro Amenábar', 'Nicole Kidman'), ('Alejandro G. Iñárritu', 'Emilio Echevarría'), ('Alejandro G. Iñárritu', 'Leonardo DiCaprio'), ('Alejandro G. Iñárritu', 'Michael Keaton'), ('Alejandro G. Iñárritu', 'Sean Penn'), ('Alejandro Jodorowsky', 'Alejandro Jodorowsky'), ('Alex Garland', 'Alicia Vikander')
# ...

# %%
group = duo.get_group(("Aamir Khan", "Amole Gupte"))
print(group)
# Out:
#         Series_Title Released_Year  Runtime  Genre  IMDB_Rating    Director  \
# 65  Taare Zameen Par          2007      165  Drama          8.4  Aamir Khan
#
#           Star1  No_of_Votes      Gross  Metascore
# 65  Amole Gupte       168895  1223869.0        NaN

# %%
# find the most earning actor->director combo..

duo['Gross'].sum().sort_values(ascending=False)
# Out:
# Director                          Star1
# Akira Kurosawa                    Toshirô Mifune               2.999877e+09
# Anthony Russo                     Joe Russo                    2.205039e+09
# Billy Wilder                      William Holden               1.286779e+09
# Christopher Nolan                 Christian Bale               1.242940e+09
# Werner Herzog                     Klaus Kinski                 1.124605e+09
# John Woo                          Yun-Fat Chow                 1.114777e+09
# Peter Jackson                     Elijah Wood                  1.035942e+09
# Stanley Kramer                    Spencer Tracy                9.871408e+08
# David Yates                       Daniel Radcliffe             9.789537e+08
# John Ford                         John Wayne                   9.544075e+08
# J.J. Abrams                       Daisy Ridley                 9.366622e+08
# Ramesh Sippy                      Sanjeev Kumar                9.320695e+08
# ...

# %%
# find the best(in terms of metascore(avg)) actor->genre combo

movies.groupby(['Star1', 'Genre'])['Metascore'].mean().reset_index().sort_values('Metascore', ascending=False).head(1)
# Out:
#               Star1  Genre  Metascore
# 230  Ellar Coltrane  Drama      100.0

# %%
# agg on multiple groupby

duo.agg(['min','max','sum']).head(4)
# Out:
#                                                   Series_Title  \
#                                                            min
# Director            Star1
# Aamir Khan          Amole Gupte               Taare Zameen Par
# Aaron Sorkin        Eddie Redmayne  The Trial of the Chicago 7
# Abdellatif Kechiche Léa Seydoux                 La vie d'Adèle
# Abhishek Chaubey    Shahid Kapoor                  Udta Punjab
#
#                                                                 \
#                                                            max
# Director            Star1
# Aamir Khan          Amole Gupte               Taare Zameen Par
# Aaron Sorkin        Eddie Redmayne  The Trial of the Chicago 7
# Abdellatif Kechiche Léa Seydoux                 La vie d'Adèle
# Abhishek Chaubey    Shahid Kapoor                  Udta Punjab
#
#                                                                Released_Year  \
# ...

# %% [markdown]
# # excercise :

# %%
ipl = pd.read_csv("IPL_Ball_by_Ball_2008_2022.csv")
ipl.head(40)
# Out:
#          ID  innings  overs  ballnumber       batter          bowler  \
# 0   1312200        1      0           1  YBK Jaiswal  Mohammed Shami
# 1   1312200        1      0           2  YBK Jaiswal  Mohammed Shami
# 2   1312200        1      0           3   JC Buttler  Mohammed Shami
# 3   1312200        1      0           4  YBK Jaiswal  Mohammed Shami
# 4   1312200        1      0           5  YBK Jaiswal  Mohammed Shami
# 5   1312200        1      0           6  YBK Jaiswal  Mohammed Shami
# 6   1312200        1      1           1   JC Buttler      Yash Dayal
# 7   1312200        1      1           2   JC Buttler      Yash Dayal
# 8   1312200        1      1           3   JC Buttler      Yash Dayal
# 9   1312200        1      1           4   JC Buttler      Yash Dayal
# 10  1312200        1      1           5   JC Buttler      Yash Dayal
# 11  1312200        1      1           6  YBK Jaiswal      Yash Dayal
# 12  1312200        1      2           1   JC Buttler  Mohammed Shami
# ...

# %%
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 225954 entries, 0 to 225953
# Data columns (total 17 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   ID                 225954 non-null  int64
#  1   innings            225954 non-null  int64
#  2   overs              225954 non-null  int64
#  3   ballnumber         225954 non-null  int64
#  4   batter             225954 non-null  object
#  5   bowler             225954 non-null  object
#  6   non-striker        225954 non-null  object
#  7   extra_type         12049 non-null   object
#  8   batsman_run        225954 non-null  int64
#  9   extras_run         225954 non-null  int64
#  10  total_run          225954 non-null  int64
#  11  non_boundary       225954 non-null  int64
#  12  isWicketDelivery   225954 non-null  int64
#  13  player_out         11151 non-null   object
#  14  kind               11151 non-null   object
# ...

# %%
# find the top 10 batsamn in terms of runs

# %%
ipl.groupby('batter')['batsman_run'].sum().sort_values(ascending=False).head(10)
# Out:
# batter
# V Kohli           6634
# S Dhawan          6244
# DA Warner         5883
# RG Sharma         5881
# SK Raina          5536
# AB de Villiers    5181
# CH Gayle          4997
# MS Dhoni          4978
# RV Uthappa        4954
# KD Karthik        4377
# Name: batsman_run, dtype: int64

# %%
# find the batsman with max no of six 

six = ipl[ipl['batsman_run']==6]

six.groupby("batter")["batter"].count().sort_values(ascending=False).head(1)
# Out:
# batter
# CH Gayle    359
# Name: batter, dtype: int64

# %%
# find the batsman with most number of 4's and 6's in the last 5 overs

temp_df = ipl[ipl["overs"]>15]
ipl[ipl[""]>15]
