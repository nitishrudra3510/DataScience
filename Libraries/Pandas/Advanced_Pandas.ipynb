# %%
import pandas as pd
import numpy as np
df = pd.read_csv("Diwali Sales Data.csv",  encoding="unicode_escape")

df.tail()



# This function returns last `n` rows from the object based on
# position. It is useful for quickly verifying data, for example,
# after sorting or appending rows.

# For negative values of `n`, this function returns all rows except
# the first `|n|` rows, equivalent to ``df[|n|:]``.

# If n is larger than the number of rows, this function returns all rows.

# Parameters
# ----------
# n : int, default 5
#     Number of rows to select.

# Returns
# -------
# type of caller
#     The last `n` rows of the caller object.
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
#                 State      Zone   Occupation Product_Category  Orders  Amount  \
# 11246     Maharashtra   Western     Chemical           Office       4   370.0
# 11247         Haryana  Northern   Healthcare       Veterinary       3   367.0
# 11248  Madhya Pradesh   Central      Textile           Office       4   213.0
# 11249       Karnataka  Southern  Agriculture           Office       3   206.0
# 11250     Maharashtra   Western   Healthcare           Office       3   188.0
#
#        Status  unnamed1
# ...

# %%
df.head()

# Return the first `n` rows.

# This function returns the first `n` rows for the object based
# on position. It is useful for quickly testing if your object
# has the right type of data in it.

# For negative values of `n`, this function returns all rows except
# the last `|n|` rows, equivalent to ``df[:n]``.

# If n is larger than the number of rows, this function returns all rows.

# Parameters
# ----------
# n : int, default 5
#     Number of rows to select.
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation Product_Category  Orders  \
# 0     Maharashtra   Western       Healthcare             Auto       1
# 1  Andhra Pradesh  Southern             Govt             Auto       3
# 2   Uttar Pradesh   Central       Automobile             Auto       3
# 3       Karnataka  Southern     Construction             Auto       2
# 4         Gujarat   Western  Food Processing             Auto       2
#
#     Amount  Status  unnamed1
# 0  23952.0     NaN       NaN
# 1  23934.0     NaN       NaN
# ...

# %%
df.tail() # prints the last 5 top rows
# Out:
#             0            1          2  3      4   5  6               7   \
# 11247  1000695      Manning  P00296942  M  18-25  19  1     Maharashtra
# 11248  1004089  Reichenbach  P00171342  M  26-35  33  0         Haryana
# 11249  1001209        Oshin  P00201342  F  36-45  40  0  Madhya Pradesh
# 11250  1004023       Noonan  P00059442  M  36-45  37  0       Karnataka
# 11251  1002744      Brumley  P00281742  F  18-25  19  0     Maharashtra
#
#              8            9           10 11   12   13   14
# 11247   Western     Chemical      Office  4  370  NaN  NaN
# 11248  Northern   Healthcare  Veterinary  3  367  NaN  NaN
# 11249   Central      Textile      Office  4  213  NaN  NaN
# 11250  Southern  Agriculture      Office  3  206  NaN  NaN
# 11251   Western   Healthcare      Office  3  188  NaN  NaN

# %%
df.tail(10) ## prints the last 10 top rows
# Out:
#             0            1          2  3      4   5  6               7   \
# 11242  1003032     Matthias  P00058042  F  26-35  33  0           Delhi
# 11243  1004344   Hildebrand  P00185442  F  26-35  27  1           Delhi
# 11244  1005446      Sheetal  P00297742  M  51-55  53  0         Gujarat
# 11245  1005446      Sheetal  P00297742  M  51-55  53  0  Madhya Pradesh
# 11246  1004140    Bertelson  P00057442  F  26-35  31  1           Delhi
# 11247  1000695      Manning  P00296942  M  18-25  19  1     Maharashtra
# 11248  1004089  Reichenbach  P00171342  M  26-35  33  0         Haryana
# 11249  1001209        Oshin  P00201342  F  36-45  40  0  Madhya Pradesh
# 11250  1004023       Noonan  P00059442  M  36-45  37  0       Karnataka
# 11251  1002744      Brumley  P00281742  F  18-25  19  0     Maharashtra
#
#              8            9           10 11   12   13   14
# 11242   Central  Hospitality      Office  3  384  NaN  NaN
# ...

# %%
s = pd.Series([1,2,3,4, np.nan,9,8], index=['a', 'b','d', 'e', 'f', 'g', 'b'])
s
# Out:
# a    1.0
# b    2.0
# d    3.0
# e    4.0
# f    NaN
# g    9.0
# b    8.0
# dtype: float64

# %%
s = pd.Series(data=s, copy=False)
s.iloc[2]=10000
s
# Out:
# a        1.0
# b        2.0
# d    10000.0
# e        4.0
# f        NaN
# g        9.0
# b        8.0
# dtype: float64

# %%
s = s.fillna(0).astype(int)
print(s.dtypes)
# Out:
# int64

# %%
s
# Out:
# a        1
# b        2
# d    10000
# e        4
# f        0
# g        9
# b        8
# dtype: int64

# %% [markdown]
# # in the series, if we assign the dict key and also indexing, then the key and indexing should be match dtypes otherwise it will give NaN values

# %%
pd.Series(
    data=None,
    index=None,
    dtype: 'Dtype | None' = None,
    name=None,
    copy: 'bool | None' = None,
    fastpath: 'bool' = False,
) -> 'None'
Docstring:
One-dimensional ndarray with axis labels (including time series).

Labels need not be unique but must be a hashable type. The object
supports both integer- and label-based indexing and provides a host of
methods for performing operations involving the index. Statistical
methods from ndarray have been overridden to automatically exclude
missing data (currently represented as NaN).

Operations between Series (+, -, /, \*, \*\*) align values based on their
associated index values-- they need not be the same length. The result
index will be the sorted union of the two indexes.

Parameters
----------
data : array-like, Iterable, dict, or scalar value
    Contains data stored in Series. If data is a dict, argument order is
    maintained.
index : array-like or Index (1d)
    Values must be hashable and have the same length as `data`.
    Non-unique index values are allowed. Will default to
    RangeIndex (0, 1, 2, ..., n) if not provided. If data is dict-like
    and index is None, then the keys in the data are used as the index. If the
    index is not None, the resulting Series is reindexed with the index values.
dtype : str, numpy.dtype, or ExtensionDtype, optional
    Data type for the output Series. If not specified, this will be
    inferred from `data`.
    See the :ref:`user guide <basics.dtypes>` for more usages.
name : Hashable, default None
    The name to give to the Series.
copy : bool, default False
    Copy input data. Only affects Series or 1d ndarray input. See examples.

Notes
-----
Please reference the :ref:`User Guide <basics.series>` for more information.

Examples
--------
Constructing Series from a dictionary with an Index specified

>>> d = {'a': 1, 'b': 2, 'c': 3}
>>> ser = pd.Series(data=d, index=['a', 'b', 'c'])
>>> ser
a   1
b   2
c   3
dtype: int64

The keys of the dictionary match with the Index values, hence the Index
values have no effect.

# %%
s
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    4.0
# 4    NaN
# 5    9.0
# 6    8.0
# dtype: float64

# %% [markdown]
# # date_and_time

# %%
Parameters
----------
start : str or datetime-like, optional
    Left bound for generating dates.
end : str or datetime-like, optional
    Right bound for generating dates.
periods : int, optional
    Number of periods to generate.
freq : str, datetime.timedelta, or DateOffset, default 'D'
    Frequency strings can have multiples, e.g. '5H'. See
    :ref:`here <timeseries.offset_aliases>` for a list of
    frequency aliases.
tz : str or tzinfo, optional
    Time zone name for returning localized DatetimeIndex, for example
    'Asia/Hong_Kong'. By default, the resulting DatetimeIndex is
    timezone-naive unless timezone-aware datetime-likes are passed.
normalize : bool, default False
    Normalize start/end dates to midnight before generating date range.
name : str, default None
    Name of the resulting DatetimeIndex.
inclusive : {"both", "neither", "left", "right"}, default "both"
    Include boundaries; Whether to set each bound as closed or open.

    .. versionadded:: 1.4.0
unit : str, default None
    Specify the desired resolution of the result.

    .. versionadded:: 2.0.0
**kwargs
    For compatibility. Has no effect on the result.


# return
Datetimeindex

# %%
dates = pd.date_range(start='1/1/2010', end='4,1,2010')
dates
# Out:
# DatetimeIndex(['2010-01-01', '2010-01-02', '2010-01-03', '2010-01-04',
#                '2010-01-05', '2010-01-06', '2010-01-07', '2010-01-08',
#                '2010-01-09', '2010-01-10', '2010-01-11', '2010-01-12',
#                '2010-01-13', '2010-01-14', '2010-01-15', '2010-01-16',
#                '2010-01-17', '2010-01-18', '2010-01-19', '2010-01-20',
#                '2010-01-21', '2010-01-22', '2010-01-23', '2010-01-24',
#                '2010-01-25', '2010-01-26', '2010-01-27', '2010-01-28',
#                '2010-01-29', '2010-01-30', '2010-01-31', '2010-02-01',
#                '2010-02-02', '2010-02-03', '2010-02-04', '2010-02-05',
#                '2010-02-06', '2010-02-07', '2010-02-08', '2010-02-09',
#                '2010-02-10', '2010-02-11', '2010-02-12', '2010-02-13',
#                '2010-02-14', '2010-02-15', '2010-02-16', '2010-02-17',
#                '2010-02-18', '2010-02-19', '2010-02-20', '2010-02-21',
# ...

# %%
dates = pd.date_range(start=('01.01.2024'), periods=5)
dates
# Out:
# DatetimeIndex(['2024-01-01', '2024-01-02', '2024-01-03', '2024-01-04',
#                '2024-01-05'],
#               dtype='datetime64[ns]', freq='D')

# %%
dates = pd.date_range(start=pd.to_datetime('3/3/2002').tz_localize("Europe/Berlin"),
                      end=pd.to_datetime('4/4/2002').tz_localize("Europe/Berlin"),)
dates
# Out:
# DatetimeIndex(['2002-03-03 00:00:00+01:00', '2002-03-04 00:00:00+01:00',
#                '2002-03-05 00:00:00+01:00', '2002-03-06 00:00:00+01:00',
#                '2002-03-07 00:00:00+01:00', '2002-03-08 00:00:00+01:00',
#                '2002-03-09 00:00:00+01:00', '2002-03-10 00:00:00+01:00',
#                '2002-03-11 00:00:00+01:00', '2002-03-12 00:00:00+01:00',
#                '2002-03-13 00:00:00+01:00', '2002-03-14 00:00:00+01:00',
#                '2002-03-15 00:00:00+01:00', '2002-03-16 00:00:00+01:00',
#                '2002-03-17 00:00:00+01:00', '2002-03-18 00:00:00+01:00',
#                '2002-03-19 00:00:00+01:00', '2002-03-20 00:00:00+01:00',
#                '2002-03-21 00:00:00+01:00', '2002-03-22 00:00:00+01:00',
#                '2002-03-23 00:00:00+01:00', '2002-03-24 00:00:00+01:00',
#                '2002-03-25 00:00:00+01:00', '2002-03-26 00:00:00+01:00',
#                '2002-03-27 00:00:00+01:00', '2002-03-28 00:00:00+01:00',
# ...

# %%
# change the feq.. to the end of month
dates = pd.date_range(start='1/1/2010', periods=10, freq='M')
dates
# Out:
# DatetimeIndex(['2010-01-31', '2010-02-28', '2010-03-31', '2010-04-30',
#                '2010-05-31', '2010-06-30', '2010-07-31', '2010-08-31',
#                '2010-09-30', '2010-10-31'],
#               dtype='datetime64[ns]', freq='M')

# %%
# mutiples in datetimeindex and 'tz' used for timezone;
dates = pd.date_range(start='01.02.2024', periods=20, freq='3M', tz="Asia/Tokyo")
dates
# Out:
# DatetimeIndex(['2024-01-31 00:00:00+09:00', '2024-04-30 00:00:00+09:00',
#                '2024-07-31 00:00:00+09:00', '2024-10-31 00:00:00+09:00',
#                '2025-01-31 00:00:00+09:00', '2025-04-30 00:00:00+09:00',
#                '2025-07-31 00:00:00+09:00', '2025-10-31 00:00:00+09:00',
#                '2026-01-31 00:00:00+09:00', '2026-04-30 00:00:00+09:00',
#                '2026-07-31 00:00:00+09:00', '2026-10-31 00:00:00+09:00',
#                '2027-01-31 00:00:00+09:00', '2027-04-30 00:00:00+09:00',
#                '2027-07-31 00:00:00+09:00', '2027-10-31 00:00:00+09:00',
#                '2028-01-31 00:00:00+09:00', '2028-04-30 00:00:00+09:00',
#                '2028-07-31 00:00:00+09:00', '2028-10-31 00:00:00+09:00'],
#               dtype='datetime64[ns, Asia/Tokyo]', freq='3M')

# %%
# `freq` can also be specified as an Offset object.

dates = pd.date_range(start='01.03.2003', periods = 5, freq=pd.offsets.MonthEnd(3))
dates
# Out:
# DatetimeIndex(['2003-01-31', '2003-04-30', '2003-07-31', '2003-10-31',
#                '2004-01-31'],
#               dtype='datetime64[ns]', freq='3M')

# %%
dates = pd.date_range(start='01.03.2003', freq='10AS', periods = 20, inclusive='left', tz='Asia/Tokyo', unit='s')
dates
# Out:
# DatetimeIndex(['2004-01-01 00:00:00+09:00', '2014-01-01 00:00:00+09:00',
#                '2024-01-01 00:00:00+09:00', '2034-01-01 00:00:00+09:00',
#                '2044-01-01 00:00:00+09:00', '2054-01-01 00:00:00+09:00',
#                '2064-01-01 00:00:00+09:00', '2074-01-01 00:00:00+09:00',
#                '2084-01-01 00:00:00+09:00', '2094-01-01 00:00:00+09:00',
#                '2104-01-01 00:00:00+09:00', '2114-01-01 00:00:00+09:00',
#                '2124-01-01 00:00:00+09:00', '2134-01-01 00:00:00+09:00',
#                '2144-01-01 00:00:00+09:00', '2154-01-01 00:00:00+09:00',
#                '2164-01-01 00:00:00+09:00', '2174-01-01 00:00:00+09:00',
#                '2184-01-01 00:00:00+09:00', '2194-01-01 00:00:00+09:00'],
#               dtype='datetime64[s, Asia/Tokyo]', freq='10AS-JAN')

# %%
datess = pd.date_range('20010303', periods=6)
datess
# Out:
# DatetimeIndex(['2001-03-03', '2001-03-04', '2001-03-05', '2001-03-06',
#                '2001-03-07', '2001-03-08'],
#               dtype='datetime64[ns]', freq='D')

# %%
import numpy as np
df1 = pd.DataFrame(np.random.randn(6,4), index=datess, columns=list('ABCD'))
df1
# Out:
#                    A         B         C         D
# 2001-03-03  1.923616  0.335697 -0.065943 -0.872657
# 2001-03-04  0.111446  1.771353 -0.251609  2.600792
# 2001-03-05 -1.102139  0.265010  0.416628  1.333367
# 2001-03-06  1.189775  1.861077  0.510585  1.219766
# 2001-03-07  1.929888 -0.375639  0.334346  0.168484
# 2001-03-08  1.700715 -0.967476  0.719576  0.752819

# %%
df2 = pd.DataFrame({
    'A': 1,
    'B':pd.Timestamp('20130102'),
    'C':pd.Series(1,index=list(range(4)), dtype=float),
    'D':np.array([3]*4, dtype='int32'),
    'E':pd.Categorical(['test', 'train', 'test', 'train']),
    'F': 'foo'
})
df2
# Out:
#    A          B    C  D      E    F
# 0  1 2013-01-02  1.0  3   test  foo
# 1  1 2013-01-02  1.0  3  train  foo
# 2  1 2013-01-02  1.0  3   test  foo
# 3  1 2013-01-02  1.0  3  train  foo

# %%
df2.dtypes # give the data types of dataframe columns..
# Out:
# A             int64
# B    datetime64[ns]
# C           float64
# D             int32
# E          category
# F            object
# dtype: object

# %%
df2.<TAB>
# Out:
#   Cell In[117], line 1
#     df2.<TAB>
#         ^
# SyntaxError: invalid syntax

# %%
# read the csv files;
# but if we don'tr want the first row to be read as the name of the column we can do this.
# unicode_escape = it doesn't gives the encoding errors

# %%
df = pd.read_csv("Diwali Sales Data.csv",encoding="unicode_escape", header=None)
df
# Out:
#             0            1           2       3          4    5   \
# 0      User_ID    Cust_name  Product_ID  Gender  Age Group  Age
# 1      1002903    Sanskriti   P00125942       F      26-35   28
# 2      1000732       Kartik   P00110942       F      26-35   35
# 3      1001990        Bindu   P00118542       F      26-35   35
# 4      1001425       Sudevi   P00237842       M       0-17   16
# ...        ...          ...         ...     ...        ...  ...
# 11247  1000695      Manning   P00296942       M      18-25   19
# 11248  1004089  Reichenbach   P00171342       M      26-35   33
# 11249  1001209        Oshin   P00201342       F      36-45   40
# 11250  1004023       Noonan   P00059442       M      36-45   37
# 11251  1002744      Brumley   P00281742       F      18-25   19
#
#                    6               7         8             9   \
# 0      Marital_Status           State      Zone    Occupation
# 1                   0     Maharashtra   Western    Healthcare
# ...

# %% [markdown]
# pd.read_csv(
#     filepath_or_buffer: 'FilePath | ReadCsvBuffer[bytes] | ReadCsvBuffer[str]',
#     *,
#     sep: 'str | None | lib.NoDefault' = <no_default>,
#     delimiter: 'str | None | lib.NoDefault' = None,
#     header: "int | Sequence[int] | None | Literal['infer']" = 'infer',
#     names: 'Sequence[Hashable] | None | lib.NoDefault' = <no_default>,
#     index_col: 'IndexLabel | Literal[False] | None' = None,
#     usecols=None,
#     dtype: 'DtypeArg | None' = None,
#     engine: 'CSVEngine | None' = None,
#     converters=None,
#     true_values=None,
#     false_values=None,
#     skipinitialspace: 'bool' = False,
#     skiprows=None,
#     skipfooter: 'int' = 0,
#     nrows: 'int | None' = None,
#     na_values=None,
#     keep_default_na: 'bool' = True,
#     na_filter: 'bool' = True,
#     verbose: 'bool' = False,
#     skip_blank_lines: 'bool' = True,
#     parse_dates: 'bool | Sequence[Hashable] | None' = None,
#     infer_datetime_format: 'bool | lib.NoDefault' = <no_default>,
#     keep_date_col: 'bool' = False,
#     date_parser=<no_default>,
#     date_format: 'str | None' = None,
#     dayfirst: 'bool' = False,
#     cache_dates: 'bool' = True,
#     iterator: 'bool' = False,
#     chunksize: 'int | None' = None,
#     compression: 'CompressionOptions' = 'infer',
#     thousands: 'str | None' = None,
#     decimal: 'str' = '.',
#     lineterminator: 'str | None' = None,
#     quotechar: 'str' = '"',
#     quoting: 'int' = 0,
#     doublequote: 'bool' = True,
#     escapechar: 'str | None' = None,
#     comment: 'str | None' = None,
#     encoding: 'str | None' = None,
#     encoding_errors: 'str | None' = 'strict',
#     dialect: 'str | csv.Dialect | None' = None,
#     on_bad_lines: 'str' = 'error',
#     delim_whitespace: 'bool' = False,
#     low_memory=True,
#     memory_map: 'bool' = False,
#     float_precision: "Literal['high', 'legacy'] | None" = None,
#     storage_options: 'StorageOptions' = None,
#     dtype_backend: 'DtypeBackend | lib.NoDefault' = <no_default>,
# ) -> 'DataFrame | TextFileReader'

# %%
df.head(3) # it gives the
# Out:
#         0          1           2       3          4    5               6   \
# 0  User_ID  Cust_name  Product_ID  Gender  Age Group  Age  Marital_Status
# 1  1002903  Sanskriti   P00125942       F      26-35   28               0
# 2  1000732     Kartik   P00110942       F      26-35   35               1
#
#                7         8           9                 10      11      12  \
# 0           State      Zone  Occupation  Product_Category  Orders  Amount
# 1     Maharashtra   Western  Healthcare              Auto       1   23952
# 2  Andhra Pradesh  Southern        Govt              Auto       3   23934
#
#        13        14
# 0  Status  unnamed1
# 1     NaN       NaN
# 2     NaN       NaN

# %% [markdown]
# # Viewing the data;
# Display the index, columns and underlying numpy the data.

# %%
df.index
# Out:
# RangeIndex(start=0, stop=11252, step=1)

# %%
Parameters
----------
start : int (default: 0), range, or other RangeIndex instance
    If int and "stop" is not given, interpreted as "stop" instead.
stop : int (default: 0)
step : int (default: 1)
dtype : np.int64
    Unused, accepted for homogeneity with other index types.
copy : bool, default False
    Unused, accepted for homogeneity with other index types.
name : object, optional
    Name to be stored in the index.

Attributes
----------
start
stop
step

# %%
range_index = df.RangeIndex(start=3, stop=10, step=1)
print(range_index)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/kq/d8w7gp1d5dn0q7qm6tzkh4pc0000gn/T/ipykernel_61536/1720513610.py in ?()
# ----> 1 range_index = df.RangeIndex(start=3, stop=10, step=1)
#       2 print(range_index)
#
# ~/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'RangeIndex'

# %%
type(df)

# dataframe in the tabular data-types
# Docstring:
# type(object) -> the object's type
# type(name, bases, dict, **kwds) -> a new type
# Out:
# pandas.core.frame.DataFrame

# %%
df = pd.read_csv("Diwali Sales Data.csv",  encoding="unicode_escape")

# %%
list(df.columns) # names of all columns..
# Out:
# ['User_ID',
#  'Cust_name',
#  'Product_ID',
#  'Gender',
#  'Age Group',
#  'Age',
#  'Marital_Status',
#  'State',
#  'Zone',
#  'Occupation',
#  'Product_Category',
#  'Orders',
#  'Amount',
#  'Status',
#  'unnamed1']

# %%
# Docstring:
# Built-in mutable sequence.

# If no argument is given, the constructor creates a new empty list.
# The argument must be an iterable if specified.
# Type:           type

# %%
df['Product_ID']

# String form:
# User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
#            0      1002903    <...>


# Parameters
# ----------
# data : ndarray (structured or homogeneous), Iterable, dict, or DataFrame
#     Dict can contain Series, arrays, constants, dataclass or list-like objects. If
#     data is a dict, column order follows insertion-order. If a dict contains Series
#     which have an index defined, it is aligned by its index. This alignment also
#     occurs if data is a Series or a DataFrame itself. Alignment is done on
#     Series/DataFrame inputs.

#     If data is a list of dicts, column order follows insertion-order.

# index : Index or array-like
#     Index to use for resulting frame. Will default to RangeIndex if
#     no indexing information part of input data and no index provided.
# columns : Index or array-like
#     Column labels to use for resulting frame when data does not have them,
#     defaulting to RangeIndex(0, 1, 2, ..., n). If data contains column labels,
#     will perform column selection instead.
# dtype : dtype, default None
#     Data type to force. Only a single dtype is allowed. If None, infer.
# copy : bool or None, default None
#     Copy data from inputs.
#     For dict data, the default of None behaves like ``copy=True``.  For DataFrame
#     or 2d ndarray input, the default of None behaves like ``copy=False``.
#     If data is a dict containing one or more Series (possibly of different dtypes),
#     ``copy=False`` will ensure that these inputs are not copied.
# Out:
# 0        P00125942
# 1        P00110942
# 2        P00118542
# 3        P00237842
# 4        P00057942
#            ...
# 11246    P00296942
# 11247    P00171342
# 11248    P00201342
# 11249    P00059442
# 11250    P00281742
# Name: Product_ID, Length: 11251, dtype: object

# %%
type(df['Product_ID']) # the data type here is Series..
# Out:
# pandas.core.series.Series

# %%
type(df[['Product_ID', 'Gender']]) # if we pass the column inside the columns, it will give the dataframe.
# Out:
# pandas.core.frame.DataFrame

# %%
#list(df["Age Group"]) # prints the all the elements of this column..

# %%
df[['Product_ID', "Gender", 'Age']] # for mutiple columns to use column inside column
# Out:
#       Product_ID Gender  Age
# 0      P00125942      F   28
# 1      P00110942      F   35
# 2      P00118542      F   35
# 3      P00237842      M   16
# 4      P00057942      M   28
# ...          ...    ...  ...
# 11246  P00296942      M   19
# 11247  P00171342      M   33
# 11248  P00201342      F   40
# 11249  P00059442      M   37
# 11250  P00281742      F   19
#
# [11251 rows x 3 columns]

# %%
df # prints the all the rows and columns
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
# ...

# %%
df.shape
# Out:
# (11251, 15)

# %%
Docstring:
Return a tuple representing the dimensionality of the DataFrame.

See Also
--------
ndarray.shape : Tuple of array dimensions.

Examples
--------
>>> df = pd.DataFrame({'col1': [1, 2], 'col2': [3, 4]})
>>> df.shape
(2, 2)
# Out:
#   Cell In[162], line 1
#     Docstring:
#                 ^
# SyntaxError: invalid syntax

# %%
df.describe()
# Out:
#             User_ID           Age  Marital_Status        Orders        Amount  \
# count  1.125100e+04  11251.000000    11251.000000  11251.000000  11239.000000
# mean   1.003004e+06     35.421207        0.420318      2.489290   9453.610858
# std    1.716125e+03     12.754122        0.493632      1.115047   5222.355869
# min    1.000001e+06     12.000000        0.000000      1.000000    188.000000
# 25%    1.001492e+06     27.000000        0.000000      1.500000   5443.000000
# 50%    1.003065e+06     33.000000        0.000000      2.000000   8109.000000
# 75%    1.004430e+06     43.000000        1.000000      3.000000  12675.000000
# max    1.006040e+06     92.000000        1.000000      4.000000  23952.000000
#
#        Status  unnamed1
# count     0.0       0.0
# mean      NaN       NaN
# std       NaN       NaN
# min       NaN       NaN
# 25%       NaN       NaN
# 50%       NaN       NaN
# 75%       NaN       NaN
# max       NaN       NaN

# %%
Signature: df.describe(zipercentiles=None, include=None, exclude=None) -> 'NDFrameT'
Docstring:
Generate descriptive statistics.

Descriptive statistics include those that summarize the central
tendency, dispersion and shape of a
dataset's distribution, excluding ``NaN`` values.

percentiles : list-like of numbers, optional
    The percentiles to include in the output. All should
    fall between 0 and 1. The default is
    ``[.25, .5, .75]``, which returns the 25th, 50th, and
    75th percentiles.

    include : 'all', list-like of dtypes or None (default), optional
    A white list of data types to include in the result. Ignored
    for ``Series``.

exclude : list-like of dtypes or None (default), optional,
    A black list of data types to omit from the result. Ignored
    for ``Series``.

# %%
# describe categorical series
d = pd.Series(['a','b','c', 'a','a'])
d.describe()
# Out:
# count     5
# unique    3
# top       a
# freq      3
# dtype: object

# %%
d1 = pd.Series([
        np.datetime64("2000-01-01"),
         np.datetime64("2010-01-01"),
        np.datetime64("2010-01-04")
 ])

d1.describe()
# Out:
# count                      3
# mean     2006-09-02 08:00:00
# min      2000-01-01 00:00:00
# 25%      2004-12-31 12:00:00
# 50%      2010-01-01 00:00:00
# 75%      2010-01-02 12:00:00
# max      2010-01-04 00:00:00
# dtype: object

# %%
# Describing all columns of a ``DataFrame`` regardless of data type.
df1.describe(include='all')
# Out:
# count                      3
# mean     2006-09-02 08:00:00
# min      2000-01-01 00:00:00
# 25%      2004-12-31 12:00:00
# 50%      2010-01-01 00:00:00
# 75%      2010-01-02 12:00:00
# max      2010-01-04 00:00:00
# dtype: object

# %%
df1 = pd.DataFrame({'categorical': pd.Categorical(['d','e','f']),
                'numeric': [1, 2, 3],
                    'object': ['a', 'b', 'c']
                   })
df1
# Out:
#   categorical  numeric object
# 0           d        1      a
# 1           e        2      b
# 2           f        3      c

# %%
df1.describe()
# Out:
#        numeric
# count      3.0
# mean       2.0
# std        1.0
# min        1.0
# 25%        1.5
# 50%        2.0
# 75%        2.5
# max        3.0

# %%
df1.describe(include='all') ## Describing all columns of a ``DataFrame`` regardless of data type.
# Out:
#        categorical  numeric object
# count            3      3.0      3
# unique           3      NaN      3
# top              d      NaN      a
# freq             1      NaN      1
# mean           NaN      2.0    NaN
# std            NaN      1.0    NaN
# min            NaN      1.0    NaN
# 25%            NaN      1.5    NaN
# 50%            NaN      2.0    NaN
# 75%            NaN      2.5    NaN
# max            NaN      3.0    NaN

# %%
df1.numeric.describe() #Describing a column from a ``DataFrame`` by accessing it as
an attribute.
# Out:
#   Cell In[192], line 2
#     an attribute.
#        ^
# SyntaxError: invalid syntax

# %%
df1.describe(include=[np.number])   #ncluding only numeric columns in a ``DataFrame``
# Out:
#        numeric
# count      3.0
# mean       2.0
# std        1.0
# min        1.0
# 25%        1.5
# 50%        2.0
# 75%        2.5
# max        3.0

# %%
df1.describe(include=[object])   #ncluding only string columns in a ``DataFrame`` or we extracted statistical inf
# Out:
#        object
# count       3
# unique      3
# top         a
# freq        1

# %%
df1.describe(include=['category'])   #ncluding only categorical columns in a ``DataFrame``
# Out:
#        categorical
# count            3
# unique           3
# top              d
# freq             1

# %%
df1.describe(exclude=[np.number])   #exclude only numerics columns in a ``DataFrame``
# Out:
#        categorical object
# count            3      3
# unique           3      3
# top              d      a
# freq             1      1

# %%
df1.describe(exclude=[object])   #exclude only object columns in a ``DataFrame``
# Out:
#        categorical  numeric
# count            3      3.0
# unique           3      NaN
# top              d      NaN
# freq             1      NaN
# mean           NaN      2.0
# std            NaN      1.0
# min            NaN      1.0
# 25%            NaN      1.5
# 50%            NaN      2.0
# 75%            NaN      2.5
# max            NaN      3.0

# %%
df1.describe(exclude=['category'])   #exclude only category columns in a ``DataFrame`` description.
# Out:
#         numeric object
# count       3.0      3
# unique      NaN      3
# top         NaN      a
# freq        NaN      1
# mean        2.0    NaN
# std         1.0    NaN
# min         1.0    NaN
# 25%         1.5    NaN
# 50%         2.0    NaN
# 75%         2.5    NaN
# max         3.0    NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   categorical  3 non-null      category
#  1   numeric      3 non-null      int64
#  2   object       3 non-null      object
# dtypes: category(1), int64(1), object(1)
# memory usage: 315.0+ bytes

# %%
df.info(
    verbose: 'bool | None' = None,
    buf: 'WriteBuffer[str] | None' = None,
    max_cols: 'int | None' = None,
    memory_usage: 'bool | str | None' = None,
    show_counts: 'bool | None' = None,
) -> 'None'

# %%
Understand the Parameters:

Each parameter is explained in the "Parameters" section:
verbose: Controls whether to print the full summary. It can be True or False.
buf: The output buffer (default is sys.stdout). You can pass a different writable buffer if needed.
max_cols: Determines when to switch from verbose to truncated output based on the number of columns.
memory_usage: Shows memory usage details. It can be True, False, or 'deep'.
show_counts: Controls whether to show non-null counts.
Check the Return Value:

The "Returns" section explains what the method returns. For df.info(), it returns None but prints the summary.

# %%
df = pd.read_csv("Diwali Sales Data.csv",  encoding="unicode_escape")
df
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
# ...

# %% [markdown]
# # Acessig the columns..

# %%
df.Cust_name
# Out:
# 0          Sanskriti
# 1             Kartik
# 2              Bindu
# 3             Sudevi
# 4               Joni
#             ...
# 11246        Manning
# 11247    Reichenbach
# 11248          Oshin
# 11249         Noonan
# 11250        Brumley
# Name: Cust_name, Length: 11251, dtype: object

# %%
df['Cust_name'] # same as above.
# Out:
# 0          Sanskriti
# 1             Kartik
# 2              Bindu
# 3             Sudevi
# 4               Joni
#             ...
# 11246        Manning
# 11247    Reichenbach
# 11248          Oshin
# 11249         Noonan
# 11250        Brumley
# Name: Cust_name, Length: 11251, dtype: object

# %%
 # This tells us the method's name (nunique), its parameters (axis and dropna), their default values (axis=0 and dropna=True), and the return type (Series).

# %%
df.nunique() # no of the unique values in each columns
# Out:
# User_ID             3755
# Cust_name           1250
# Product_ID          2351
# Gender                 2
# Age Group              7
# Age                   81
# Marital_Status         2
# State                 16
# Zone                   5
# Occupation            15
# Product_Category      18
# Orders                 4
# Amount              6584
# Status                 0
# unnamed1               0
# dtype: int64

# %% [markdown]
# # Reshaping.. and Pivot table
# It provides mehtod for manipulating a Series and dataframe to alter the represtation of the data for further data processing or data summerization..

# %% [markdown]
# pivot() and pivot_table(): Group unique values within one or more discrete categories.

# %% [markdown]
# #Pivot()
#
# ![image.png](data:image/png;base64,...)

# %%
# data stored in the "stacked or record" format. In a “record” or “wide” format, typically there is one row for each subject. In the “stacked” or “long” format there are multiple rows for each subject where applicable.
import pandas as pd
data={
    "value":range(12),
    "variable": ["A"]*3 + ["B"]*3+["C"]*3 + ["D"]*3,
    "date": pd.to_datetime(["2020-01-03", "2020-01-04", "2020-01-05"]*4)

}

df = pd.DataFrame(data)

# %%
# To reshape the data into this form, we use the DataFrame.pivot() method (also implemented as a top level function pivot()):

pivoted = df.pivot(index='date', columns = "variable", values="value")

pivoted
# Out:
# variable    A  B  C   D
# date
# 2020-01-03  0  3  6   9
# 2020-01-04  1  4  7  10
# 2020-01-05  2  5  8  11

# %%
df["value2"] = df["value"]*2
pivoted = df.pivot(index="date", columns ="variable")
pivoted
# Out:
#            value           value2
# variable       A  B  C   D      A   B   C   D
# date
# 2020-01-03     0  3  6   9      0   6  12  18
# 2020-01-04     1  4  7  10      2   8  14  20
# 2020-01-05     2  5  8  11      4  10  16  22

# %% [markdown]
# You can then select subsets from the pivoted DataFrame:

# %%
pivoted["value2"]
# Out:
# variable    A   B   C   D
# date
# 2020-01-03  0   6  12  18
# 2020-01-04  2   8  14  20
# 2020-01-05  4  10  16  22

# %% [markdown]
# # pivot() can only handle unique rows specified by index and columns. If you data contains duplicates, use pivot_table().

# %% [markdown]
# # melt() and wide_to_long()
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # JOin and Append
# Join columns with other DataFrame either on index or on a key column. Efficiently join multiple DataFrame objects by index at once by passing a list.
#
#
# ![image.png](data:image/png;base64,...)

# %%
var1 = pd.DataFrame({"A":[1,2,3,4], "B":[5,6,7,8]})
var2 = pd.DataFrame({"c":[10,20], "D":[11,22]})
var1.join(var2)
# Out:
#    A  B     c     D
# 0  1  5  10.0  11.0
# 1  2  6  20.0  22.0
# 2  3  7   NaN   NaN
# 3  4  8   NaN   NaN

# %%
var1.join(var2)
# Out:
#    A  B     c     D
# 0  1  5  10.0  11.0
# 1  2  6  20.0  22.0
# 2  3  7   NaN   NaN
# 3  4  8   NaN   NaN

# %%
var2.join(var1)
# Out:
#     c   D  A  B
# 0  10  11  1  5
# 1  20  22  2  6

# %%
var2.join(var1, how='right')
# Out:
#       c     D  A  B
# 0  10.0  11.0  1  5
# 1  20.0  22.0  2  6
# 2   NaN   NaN  3  7
# 3   NaN   NaN  4  8

# %%
var2.join(var1, how='left')
# Out:
#     c   D  A  B
# 0  10  11  1  5
# 1  20  22  2  6

# %%
var2.join(var1, how='outer')
# Out:
#       c     D  A  B
# 0  10.0  11.0  1  5
# 1  20.0  22.0  2  6
# 2   NaN   NaN  3  7
# 3   NaN   NaN  4  8

# %%
var2.join(var1, how='inner')
# Out:
#     c   D  A  B
# 0  10  11  1  5
# 1  20  22  2  6

# %%
var1 = pd.DataFrame({"A":[1,2,3,4], "B":[5,6,7,8]})
var2 = pd.DataFrame({"c":[10,20], "B":[11,22]})
var2.join(var1, how='inner', lsuffix='_12')
# Out:
#     c  B_12  A  B
# 0  10    11  1  5
# 1  20    22  2  6

# %%
var2.join(var1, how='outer', rsuffix='_12')
# Out:
#       c     B  A  B_12
# 0  10.0  11.0  1     5
# 1  20.0  22.0  2     6
# 2   NaN   NaN  3     7
# 3   NaN   NaN  4     8

# %% [markdown]
# Join DataFrames using their indexes.

# %%
var1.join(var2, lsuffix='_12', rsuffix='_25')
# Out:
#    A  B_12     c  B_25
# 0  1     5  10.0  11.0
# 1  2     6  20.0  22.0
# 2  3     7   NaN   NaN
# 3  4     8   NaN   NaN

# %% [markdown]
# If we want to join using the key columns, we need to set key to be the index in both df and other. The joined DataFrame will have key as its index.

# %%
df = pd.DataFrame({'key': ['K0', 'K1', 'K2', 'K3', 'K4', 'K5'],
                   'A': ['A0', 'A1', 'A2', 'A3', 'A4', 'A5']})

# %%
other = pd.DataFrame({'key': ['K0', 'K1', 'K2'],
                      'B': ['B0', 'B1', 'B2']})

# %%
df.set_index('key').join(other.set_index('key'))
# Out:
#       A    B
# key
# K0   A0   B0
# K1   A1   B1
# K2   A2   B2
# K3   A3  NaN
# K4   A4  NaN
# K5   A5  NaN

# %% [markdown]
# Using non-unique key values shows how they are matched

# %%
df = pd.DataFrame({'key': ['K0', 'K1', 'K1', 'K3', 'K0', 'K1'],
                   'A': ['A0', 'A1', 'A2', 'A3', 'A4', 'A5']})
df
# Out:
#   key   A
# 0  K0  A0
# 1  K1  A1
# 2  K1  A2
# 3  K3  A3
# 4  K0  A4
# 5  K1  A5

# %%
df.join(other.set_index('key'), on='key', validate='m:1')
# Out:
#   key   A    B
# 0  K0  A0   B0
# 1  K1  A1   B1
# 2  K1  A2   B1
# 3  K3  A3  NaN
# 4  K0  A4   B0
# 5  K1  A5   B1

# %%
# append()

var1 = pd.DataFrame({"A":[1,2,3,4], "B":[5,6,7,8]}, index=['a', 'b', 'c', 'd'])
var2 = pd.DataFrame({"c":[10,20], "B":[11,22]},index=['a','b'])

result = pd.concat([var1, var2])
result
# Out:
#      A   B     c
# a  1.0   5   NaN
# b  2.0   6   NaN
# c  3.0   7   NaN
# d  4.0   8   NaN
# a  NaN  11  10.0
# b  NaN  22  20.0

# %%
result = pd.concat([var1, var2], ignore_index=True)
result
# Out:
#      A   B     c
# 0  1.0   5   NaN
# 1  2.0   6   NaN
# 2  3.0   7   NaN
# 3  4.0   8   NaN
# 4  NaN  11  10.0
# 5  NaN  22  20.0
