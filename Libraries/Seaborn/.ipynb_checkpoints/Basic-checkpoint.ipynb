# %%
# install the library
pip install seaborn
# Out:
# Requirement already satisfied: seaborn in /Users/nitishkumar/anaconda3/lib/python3.11/site-packages (0.12.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in /Users/nitishkumar/anaconda3/lib/python3.11/site-packages (from seaborn) (1.24.3)
# Requirement already satisfied: pandas>=0.25 in /Users/nitishkumar/anaconda3/lib/python3.11/site-packages (from seaborn) (2.0.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in /Users/nitishkumar/anaconda3/lib/python3.11/site-packages (from seaborn) (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/nitishkumar/anaconda3/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /Users/nitishkumar/anaconda3/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/nitishkumar/anaconda3/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/nitishkumar/anaconda3/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Users/nitishkumar/anaconda3/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /Users/nitishkumar/anaconda3/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.4.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /Users/nitishkumar/anaconda3/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/nitishkumar/anaconda3/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/nitishkumar/anaconda3/lib/python3.11/site-packages (from pandas>=0.25->seaborn) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/nitishkumar/anaconda3/lib/python3.11/site-packages (from pandas>=0.25->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in /Users/nitishkumar/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# import the library
import seaborn as sns
import matplotlib.pyplot as plt # often used to aloneside seaborns

# %% [markdown]
# # Built in Datasets

# %%
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# # Basics Plotting Functions:

# %%
# Scatter Plot 
sns.scatterplot(data=tips, x = "total_bill", y="tip", hue="time")
plt.show()

# to use the (data = tips) - to use the specific tips data
# (x = "total_bill") - it represent the values of total_bill on the x-axis...
# y="tip" - it represent the values of tips on the y- axis
# hue="time" - it will point of the color (dinner or lunch).

# %% [markdown]
# # bar plot

# %%
sns.barplot(data=tips, x = "day", y="total_bill", hue="sex")
plt.show()

# %% [markdown]
# # Histogram

# %%
sns.histplot(data=tips, x = "total_bill", bins=20, kde=True)
plt.show()

# %% [markdown]
# # Line Plot

# %%
sns.lineplot(data=tips, x = "size", y="total_bill", ci=None)
plt.show
# Out:
# /var/folders/kq/d8w7gp1d5dn0q7qm6tzkh4pc0000gn/T/ipykernel_10618/4274534249.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(data=tips, x = "size", y="total_bill", ci=None)
# <function matplotlib.pyplot.show(close=None, block=None)>
