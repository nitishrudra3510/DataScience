# %% [markdown]
#  # Parametric-Density-Estimation

# %%
import matplotlib.pyplot as plt
import numpy as np
from numpy.random import normal

# %%
sample = normal(loc=50, scale=5, size=1000)

# %%
sample
# Out:
# array([52.82246744, 46.35024617, 44.49732079, 54.72136934, 42.68618597,
#        52.53377467, 64.74001226, 43.85227087, 41.38870636, 44.95866453,
#        54.92450503, 46.48166295, 43.53424866, 58.62917651, 46.05629106,
#        49.83950707, 46.85963471, 46.44742061, 44.16712613, 45.89714673,
#        48.56228314, 53.34826639, 54.12472958, 46.09544047, 53.19905309,
#        55.31281859, 52.24300954, 56.06811075, 45.59102353, 61.81540448,
#        52.15868191, 56.17871562, 44.22925157, 51.97033842, 54.22598927,
#        53.88669805, 44.81417339, 47.66532199, 52.04931898, 51.94262302,
#        55.82486645, 56.44084062, 53.97224005, 54.67602432, 46.99462441,
#        55.15986251, 52.09402331, 55.07683376, 50.80786014, 48.75152983,
#        55.07340195, 42.97099829, 50.30712337, 59.91006283, 54.54489124,
#        55.06796213, 51.78894836, 44.23688569, 42.59723092, 52.77255179,
#        52.29919493, 43.08404858, 49.13471971, 63.5097582 , 59.48971401,
# ...

# %%
sample.mean()
# Out:
# 50.28491817100493

# %%
# plot the histogram to understand the distribution of data..

plt.hist(sample, bins=10)
# Out:
# (array([  8.,  38., 125., 238., 273., 196.,  87.,  27.,   6.,   2.]),
#  array([34.92416465, 38.45677463, 41.9893846 , 45.52199458, 49.05460455,
#         52.58721453, 56.1198245 , 59.65243448, 63.18504445, 66.71765443,
#         70.2502644 ]),
#  <BarContainer object of 10 artists>)

# %%
# to  calculate the sample means and sample std dev..

sample_mean = sample.mean()
sample_std = sample.std()

# %%
# fit the distribution with the above parameters

from scipy.stats import norm

dist = norm(sample_mean, sample_std)

# %%
values = np.linspace(sample.min(), sample.max(), 100)

# %%
sample.max()
# Out:
# 70.25026440205998

# %%
probabilities = [dist.pdf(value) for value in values]

# %%
# plot the histogram and pdf

plt.hist(sample, bins=10, density=True)
plt.plot(values, probabilities)

# %%
import seaborn as sns
sns.distplot(sample)
# Out:
# /var/folders/kq/d8w7gp1d5dn0q7qm6tzkh4pc0000gn/T/ipykernel_43677/1482356190.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(sample)
# <Axes: ylabel='Density'>

# %% [markdown]
# if the paramter has close to the polpulation parameter then the estimation will be good other wise not..
#
# agar data bahut jayada nahi hai to population paramter estimate nahi kar payega sahi se..
