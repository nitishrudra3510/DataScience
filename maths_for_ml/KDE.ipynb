# %% [markdown]
# # KDE

# %%
import matplotlib.pyplot as plt
import numpy as np
from numpy.random import normal

# %%
# generate a sample 
sample1 = normal(loc=20, scale=5, size=300) # loc=mean, scale = std
sample2 = normal(loc=40, scale=5   , size=700)
sample = np.hstack((sample1, sample2))

# %%
sample
# Out:
# array([19.44076074, 20.9171447 , 12.72961364, 35.47639976, 15.75750013,
#        26.23078996, 24.51842208, 32.56621629, 13.53456282, 18.51333985,
#        18.95720105, 21.18323694, 15.85355683, 18.46868258, 23.17373407,
#        21.55679381, 25.34104557, 20.87954088, 21.68335073, 15.89120596,
#        11.76042247, 15.51029022, 19.64186222, 24.92429719, 25.47140007,
#        22.3820677 , 18.94084802, 19.64347971, 18.7847972 , 11.74238024,
#        27.04710138, 21.19434834, 20.55180407, 12.0609878 , 23.65836161,
#        22.57022395, 13.4196485 , 23.23147058, 23.35663133,  5.55824828,
#        22.42065277, 13.97021234, 29.75740716, 12.29486224, 25.09586205,
#        24.53570227, 15.1347046 , 25.45259767, 22.46037631, 16.27805977,
#        19.45303117, 24.10067514, 11.88468219, 20.59182467, 23.57144232,
#        24.17321267, 18.37368442, 20.35711365, 25.66130039, 24.00018837,
#        20.78328599, 25.80076923, 15.9355348 , 10.11391383, 15.37146926,
# ...

# %%
# plot histogram bins=50
plt.hist(sample, bins=50)
# Out:
# (array([ 3.,  3.,  0.,  0.,  4.,  6.,  8.,  6.,  9., 12., 15., 12., 14.,
#         13., 23., 30., 25., 23., 21., 19., 18., 18., 13.,  6.,  7., 18.,
#         10., 18.,  9., 21., 25., 47., 38., 41., 58., 47., 64., 51., 44.,
#         44., 41., 19., 23., 25., 20.,  6.,  6.,  8.,  8.,  1.]),
#  array([ 5.55824828,  6.51221738,  7.46618649,  8.42015559,  9.3741247 ,
#         10.3280938 , 11.28206291, 12.23603201, 13.19000112, 14.14397022,
#         15.09793933, 16.05190843, 17.00587754, 17.95984664, 18.91381575,
#         19.86778485, 20.82175396, 21.77572306, 22.72969217, 23.68366127,
#         24.63763038, 25.59159948, 26.54556859, 27.49953769, 28.4535068 ,
#         29.4074759 , 30.36144501, 31.31541411, 32.26938322, 33.22335232,
#         34.17732143, 35.13129053, 36.08525964, 37.03922874, 37.99319785,
#         38.94716695, 39.90113606, 40.85510516, 41.80907427, 42.76304337,
#         43.71701248, 44.67098158, 45.62495069, 46.57891979, 47.5328889 ,
# ...

# %% [markdown]
# this is not like a normal dis.. or other. it's look like other distribution so that I will used to non-parametric distributions

# %%
from sklearn.neighbors import KernelDensity

model = KernelDensity(bandwidth=3, kernel="gaussian")

# convert data to a 2D array because many ml alg work on 2D array..

sample = sample.reshape(len(sample), 1) 

model.fit(sample)
# Out:
# KernelDensity(bandwidth=3)

# %%
values = np.linspace(sample.min(), sample.max(), 100)

values = values.reshape(len(values), 1)

# %%
probabilities = model.score_samples(values)

probabilities = np.exp(probabilities)

# %% [markdown]
# score_samples (values) returns the log density estimate of the input samples values. This is because the score_samples method of the KernelDensity class returns the logarithm of the probability density estimate rather than the actual probability density estimate.

# %%
plt.hist(sample, bins=50, density=True)

plt.plot(values[:], probabilities)

plt.show()

# %% [markdown]
# if the bandwith give the minimum then it will shows as a peak graph..

# %%
from sklearn.neighbors import KernelDensity

model = KernelDensity(bandwidth=0.5, kernel="gaussian")

# convert data to a 2D array because many ml alg work on 2D array..

sample = sample.reshape(len(sample), 1) 

model.fit(sample)
# Out:
# KernelDensity(bandwidth=0.5)

# %%
values = np.linspace(sample.min(), sample.max(), 100)

values = values.reshape(len(values), 1)

# %%
probabilities = model.score_samples(values)

probabilities = np.exp(probabilities)

# %%
plt.hist(sample, bins=50, density=True)

plt.plot(values[:], probabilities)

plt.show()

# %% [markdown]
# see this..

# %%
import seaborn as sns
sns.kdeplot(sample.reshape(1000), bw_adjust=2)
# Out:
# <Axes: ylabel='Density'>

# %%
import seaborn as sns
sns.kdeplot(sample.reshape(1000), bw_adjust=0.02)
# Out:
# <Axes: ylabel='Density'>
